# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader, Subset, random_split
import torch.nn.utils.weight_norm as weight_norm
import torch.nn.functional as F
import numpy as np
import scipy as sp
from scipy.stats import norm, shapiro, binom
from scipy.special import beta

import matplotlib.pyplot as plt
import random
import time as t
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_covtype, fetch_openml, fetch_20newsgroups
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
import os
import urllib
import gzip
import zipfile
import json
from datetime import datetime

from sklearn.feature_extraction.text import TfidfVectorizer
import datasets
from datasets import load_dataset
import seaborn as sns
import ipynbname
from collections import defaultdict

notebook_name = ipynbname.name()
# from torchtime.data import PhysioNet2012
# from torchtime.collate import packed_sequence

# %%
# ✅ 1. Config

device_id = 3
device = "cuda:"+str(device_id) if torch.cuda.is_available() else 'cpu'

BATCH_SIZE = 128
DATA_PATH = './data'
SEED = 42
torch.manual_seed(SEED)

# ✅ Load data
data = fetch_covtype()
X = data.data       # shape (581012, 54)
y = data.target - 1 # Labels are 1-based, shift to 0-based for PyTorch CrossEntropyLoss

# ✅ Preprocess (standardize only continuous columns)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# ✅ Split train/test
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# ✅ Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# ✅ Wrap in DataLoaders
BATCH_SIZE = 128
train_data = TensorDataset(X_train_tensor, y_train_tensor)
test_data = TensorDataset(X_test_tensor, y_test_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
class MLP(nn.Module):
    # For UCI Income: input_dim=X_train_tensor.shape[1], hidden_dims=[64, 32], output_dim=2,
    # For CoverType input_dim=54, hidden_dims=[256, 128, 64], output_dim=7,
    # CIFAR-10 its input_dim=3072, hidden_dims=[2048, 1024, 1024, 512, 256, 128], output_dim=10,
    # CIFAR-100 its input_dim=3072, hidden_dims=[2048, 1024, 1024, 512], output_dim=100,
    # For FashionMNIST its input_dim=784, hidden_dims=[512, 256, 128], output_dim=10, dropout=0.2,
    # For Yelp dataset input_dim=10000, hidden_dims=[512], output_dim=2, 
    # For 20Newsgroups input_dim=2000, hidden_dims=[512, 256, 128], num_classes=20
    def __init__(self, input_dim=54, hidden_dims=[256, 128, 64], output_dim=7, dropout=0.3, activation_fn=nn.ReLU, use_mask=True, threshold=1):
        super(MLP, self).__init__()
        self.activation = activation_fn()
        self.use_mask = use_mask
        layers = []
        dims = [input_dim] + hidden_dims
        self.table = {}
        x_vals = np.linspace(0,1,100000)
        for b in dims:
            self.table[b] = sp.special.betainc(1/2, 0.5*(b - 1), x_vals)

        for i in range(len(dims) - 1):
            layers += [
                MaskedLinear(dims[i], dims[i+1], use_mask=self.use_mask, threshold=threshold, table=self.table),
                # nn.BatchNorm1d(dims[i+1]),
                self.activation,
                # nn.Dropout(dropout)
            ]
    
        layers.append(MaskedLinear(dims[-1], output_dim, use_mask=self.use_mask, threshold=threshold, table=self.table))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

class MaskedLinear(nn.Linear):
    def __init__(self, in_features, out_features, bias=True, threshold=1, use_mask=True, table={}):
        super().__init__(in_features, out_features, bias)
        self.threshold = torch.tensor(threshold) #-torch.log10()
        self.use_mask = use_mask
        self.register_buffer("entropy", torch.tensor(0.0))
        self.table = table
        self.register_buffer("w_values", torch.zeros_like(self.weight))
        
    def wval(self, M):
        a = t.time()
        L = M.shape[1] if M.ndim == 2 else M.shape[1] * M.shape[2] * M.shape[3]

        alpha = torch.as_tensor(1/2, dtype=M.dtype, device=M.device)
        beta = torch.as_tensor((L-1)/2, dtype=M.dtype, device=M.device)
    
        # Normalize each weight vector going from a node in A to layer B
        M_normed = F.normalize(M, p=2, dim=1)
        
        M_clamped = torch.clamp(M_normed**2, min=1e-8, max=1-1e-8)

        M_cpu = M_clamped.detach().cpu().numpy()
        alpha_cpu = float(alpha.item())  # scalar
        beta_cpu = float(beta.item())    # scalar
        
        index_matrix = np.round(100000 * M_cpu).astype(int)
        
        # Optional: clamp to [0, 100] just in case of rounding errors
        index_matrix = np.clip(index_matrix, 0, 100000)
        
        # Step 2: Use advanced NumPy indexing
        table_vals = np.array(self.table[L])  # Make sure this is a NumPy array
        cdf_np = table_vals[index_matrix]     # Fast lookup for entire matrix
        
        cdf = torch.tensor(cdf_np, dtype=M_clamped.dtype, device=M_clamped.device)

        beta_surv = torch.clamp(1 - cdf, min=1e-8, max=1-1e-8)  # Survival function
        
        w_val = -torch.log(beta_surv)

        assert w_val.shape == M.shape

        return w_val

    def forward(self, input):
        if self.use_mask:
            # Compute significance
            self.w_values = self.wval(self.weight)
    
            # Create binary mask
            mask = (self.w_values >= self.threshold).float()
    
            # Apply the mask (zero out insignificant weights)
            masked_weight = self.weight * mask
        else:
            masked_weight = self.weight
            self.w_values = self.wval(self.weight)

        flat_M = torch.flatten(masked_weight)
        flat_M_2 = flat_M.pow(2)

        entropy_value = sp.stats.entropy(flat_M_2.detach().cpu().numpy())
        ent_tensor = torch.tensor(entropy_value)
        self.entropy.copy_(ent_tensor)
        return F.linear(input, masked_weight, self.bias)

# %%
def save_run_data_txt(
    base_dir, model, config, train_losses, train_accuracies,
    test_losses, test_accuracies
):
    # Create a unique folder name
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    folder_name = (
        f"{timestamp}_act-{config['activation']}_mask-{config['use_mask']}"
        f"_thresh-{round(config['threshold'],2)}_reg-{config['regularization']}_epochs-{config['epochs']}-{notebook_name}"
    )
    path = os.path.join(base_dir, folder_name)
    os.makedirs(path, exist_ok=True)

    # Save model weights
    torch.save(model.state_dict(), os.path.join(path, "model.pth"))

    # Save run configuration
    with open(os.path.join(path, "config.json"), "w") as f:
        json.dump(config, f, indent=4)

    # Helper function to write a list of floats to a .txt file
    def write_list(filename, values):
        with open(os.path.join(path, filename), "w") as f:
            for v in values:
                f.write(f"{v:.6f}\n")

    # Save all metrics
    write_list("train_losses.txt", train_losses)
    write_list("train_accuracies.txt", train_accuracies)
    write_list("test_losses.txt", test_losses)
    write_list("test_accuracies.txt", test_accuracies)

    print(f"Run data saved to {path}")

    return folder_name

# %%
def train_and_collect_metrics(
    train_loader,
    test_loader,
    act,
    use_mask,
    regularization=None,
    lambda_reg=0.0,
    initial_weights=None,
    epochs=5,
    the_device='cpu',
    threshold=1,
):
    model = MLP(activation_fn=act, use_mask=use_mask, threshold=threshold).to(the_device)
        
    if initial_weights is not None:
        model.load_state_dict({k: v.clone().to(the_device) for k, v in initial_weights.items()})

    model = model.to(the_device)
    model = nn.DataParallel(model, device_ids=[device_id])

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(the_device), labels.to(the_device)
            optimizer.zero_grad()
            output = model(images)
            loss = criterion(output, labels)

            if regularization == "L1" and lambda_reg > 0:
                reg_term = sum(p.abs().sum() for p in model.parameters())
                loss += lambda_reg * reg_term
            elif regularization == "L2" and lambda_reg > 0:
                reg_term = sum((p ** 2).sum() for p in model.parameters())
                loss += lambda_reg * reg_term

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            predicted = output.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        avg_loss = epoch_loss / len(train_loader)
        accuracy = 100 * correct / total
        train_losses.append(avg_loss)
        train_accuracies.append(accuracy)
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_loss:.4f}, Train Accuracy: {accuracy:.2f}%")

        # Compute test loss every 10 epochs
        if (epoch + 1) % 5 == 0 or epoch == epochs - 1:
            model.eval()
            test_loss = 0.0
            correct = 0
            total = 0
            with torch.no_grad():
                for images, labels in test_loader:
                    images, labels = images.to(the_device), labels.to(the_device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    test_loss += loss.item()
                    predicted = outputs.argmax(dim=1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
            avg_test_loss = test_loss / len(test_loader)
            test_acc = 100 * correct / total
            test_losses.append(avg_test_loss)
            test_accuracies.append(test_acc)
            print(f"[Epoch {epoch+1}] Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

    # Final test evaluation
    model.eval()
    correct = 0
    total = 0
    total_loss = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(the_device), labels.to(the_device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            predicted = outputs.argmax(dim=1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = total_loss / len(test_loader)
    test_accuracy = 100 * correct / total
    print(f"[use_mask={use_mask}, reg={regularization}] Final Test Accuracy: {test_accuracy:.2f}%, Test Loss: {test_loss:.4f}")
    
    
    config = {
    "activation": act.__name__ if hasattr(act, "__name__") else str(act),
    "use_mask": use_mask,
    "threshold": threshold,
    "regularization": regularization,
    "lambda_reg": lambda_reg,
    "epochs": epochs,
    "device": the_device,
    }

    folder_name = save_run_data_txt(
        base_dir="runs_"+notebook_name,
        model=model,
        config=config,
        train_losses=train_losses,
        train_accuracies=train_accuracies,
        test_losses=test_losses,
        test_accuracies=test_accuracies,
    )
    
    return model.module, test_losses, test_accuracies, train_losses, train_accuracies, folder_name

# %%
torch.manual_seed(42)
EPOCHS = 100
#THRESHOLD = 0.4

baseline_model = MLP(activation_fn = nn.ReLU, use_mask=False, threshold=0.7).cpu()
# Save baseline weights
initial_weights = {k: v.clone().detach().cpu() for k, v in baseline_model.state_dict().items()}

# Run all configurations
model_results = {}
test_losses = {}
times = {}
test_accs = {}
train_losses = {}
train_accs = {}
folder_names = []

configs = [
    # ("ReLU_NoMask_NoReg", nn.ReLU, False, None, 0.0, 0.7),
    ("ReLU_NoMask_L1", nn.ReLU, False, "L1", 1e-6, 0.7),
    # ("ReLU_NoMask_L2", nn.ReLU, False, "L2", 1e-6, 0.7),
    ("ReLU_Mask_NoReg_t1", nn.ReLU, True, None, 0.0, -np.log(0.90)),
    # ("ReLU_Mask_NoReg_t2", nn.ReLU, True, None, 0.0, -np.log(0.75)),
    ("ReLU_Mask_NoReg_t3", nn.ReLU, True, None, 0.0, -np.log(0.50)),
    ("ReLU_Mask_NoReg_t4", nn.ReLU, True, None, 0.0, -np.log(0.25)),
    ("ReLU_Mask_NoReg_t5", nn.ReLU, True, None, 0.0, -np.log(0.10)),
    # ("Sigmoid_NoMask_NoReg", nn.Sigmoid, False, None, 0.0, 0.7),
    # ("Sigmoid_NoMask_L1", nn.Sigmoid, False, "L1", 1e-6, 0.7),
    # ("Sigmoid_Mask_NoReg", nn.Sigmoid, True, None, 0.0, 0.7),
]

start = t.time()

for label, act, use_mask, reg_type, lambd, thresh in configs:
    iter_i = t.time()
    model, test_loss, test_acc, train_loss, train_acc, folder_name = train_and_collect_metrics(train_loader, test_loader, act, use_mask, reg_type, lambd, initial_weights, epochs=EPOCHS, the_device=device, threshold=thresh)
    test_losses[label] = test_loss
    model_results[label] = model
    test_accs[label] = test_acc
    train_losses[label] = train_loss
    train_accs[label] = train_acc

    folder_names.append(folder_name)
    iter_f = t.time()
    delta = iter_f - iter_i
    print(delta)
    times[label] = delta
    
total = t.time() - start
print(total/60)
# Out:
# Epoch 1/100 - Train Loss: 0.6898, Train Accuracy: 71.92%
# Epoch 2/100 - Train Loss: 0.5617, Train Accuracy: 76.16%
# Epoch 3/100 - Train Loss: 0.5221, Train Accuracy: 77.64%
# Epoch 4/100 - Train Loss: 0.4941, Train Accuracy: 78.84%
# Epoch 5/100 - Train Loss: 0.4712, Train Accuracy: 80.08%
# [Epoch 5] Test Loss: 0.4602, Test Accuracy: 80.75%
# Epoch 6/100 - Train Loss: 0.4527, Train Accuracy: 81.02%
# Epoch 7/100 - Train Loss: 0.4370, Train Accuracy: 81.89%
# Epoch 8/100 - Train Loss: 0.4238, Train Accuracy: 82.48%
# Epoch 9/100 - Train Loss: 0.4120, Train Accuracy: 83.07%
# Epoch 10/100 - Train Loss: 0.4013, Train Accuracy: 83.53%
# [Epoch 10] Test Loss: 0.3946, Test Accuracy: 84.02%
# Epoch 11/100 - Train Loss: 0.3915, Train Accuracy: 84.00%
# Epoch 12/100 - Train Loss: 0.3834, Train Accuracy: 84.36%
# Epoch 13/100 - Train Loss: 0.3758, Train Accuracy: 84.75%
# Epoch 14/100 - Train Loss: 0.3690, Train Accuracy: 85.07%
# Epoch 15/100 - Train Loss: 0.3624, Train Accuracy: 85.31%
# [Epoch 15] Test Loss: 0.3613, Test Accuracy: 85.23%
# Epoch 16/100 - Train Loss: 0.3564, Train Accuracy: 85.57%
# Epoch 17/100 - Train Loss: 0.3509, Train Accuracy: 85.85%
# Epoch 18/100 - Train Loss: 0.3455, Train Accuracy: 86.08%
# Epoch 19/100 - Train Loss: 0.3416, Train Accuracy: 86.26%
# Epoch 20/100 - Train Loss: 0.3361, Train Accuracy: 86.47%
# [Epoch 20] Test Loss: 0.3346, Test Accuracy: 86.42%
# Epoch 21/100 - Train Loss: 0.3320, Train Accuracy: 86.66%
# Epoch 22/100 - Train Loss: 0.3286, Train Accuracy: 86.86%
# Epoch 23/100 - Train Loss: 0.3251, Train Accuracy: 86.95%
# Epoch 24/100 - Train Loss: 0.3209, Train Accuracy: 87.15%
# Epoch 25/100 - Train Loss: 0.3178, Train Accuracy: 87.28%
# [Epoch 25] Test Loss: 0.3214, Test Accuracy: 87.07%
# Epoch 26/100 - Train Loss: 0.3141, Train Accuracy: 87.46%
# Epoch 27/100 - Train Loss: 0.3110, Train Accuracy: 87.59%
# Epoch 28/100 - Train Loss: 0.3077, Train Accuracy: 87.76%
# Epoch 29/100 - Train Loss: 0.3054, Train Accuracy: 87.87%
# Epoch 30/100 - Train Loss: 0.3027, Train Accuracy: 87.96%
# [Epoch 30] Test Loss: 0.3076, Test Accuracy: 87.63%
# Epoch 31/100 - Train Loss: 0.2993, Train Accuracy: 88.14%
# Epoch 32/100 - Train Loss: 0.2969, Train Accuracy: 88.25%
# Epoch 33/100 - Train Loss: 0.2940, Train Accuracy: 88.34%
# Epoch 34/100 - Train Loss: 0.2917, Train Accuracy: 88.42%
# Epoch 35/100 - Train Loss: 0.2894, Train Accuracy: 88.55%
# [Epoch 35] Test Loss: 0.3178, Test Accuracy: 87.15%
# Epoch 36/100 - Train Loss: 0.2873, Train Accuracy: 88.64%
# Epoch 37/100 - Train Loss: 0.2851, Train Accuracy: 88.73%
# Epoch 38/100 - Train Loss: 0.2827, Train Accuracy: 88.82%
# Epoch 39/100 - Train Loss: 0.2804, Train Accuracy: 88.93%
# Epoch 40/100 - Train Loss: 0.2783, Train Accuracy: 89.01%
# [Epoch 40] Test Loss: 0.2859, Test Accuracy: 88.62%
# Epoch 41/100 - Train Loss: 0.2766, Train Accuracy: 89.10%
# Epoch 42/100 - Train Loss: 0.2744, Train Accuracy: 89.19%
# Epoch 43/100 - Train Loss: 0.2727, Train Accuracy: 89.24%
# Epoch 44/100 - Train Loss: 0.2711, Train Accuracy: 89.28%
# Epoch 45/100 - Train Loss: 0.2688, Train Accuracy: 89.41%
# [Epoch 45] Test Loss: 0.2762, Test Accuracy: 89.05%
# Epoch 46/100 - Train Loss: 0.2670, Train Accuracy: 89.46%
# Epoch 47/100 - Train Loss: 0.2651, Train Accuracy: 89.59%
# Epoch 48/100 - Train Loss: 0.2642, Train Accuracy: 89.62%
# Epoch 49/100 - Train Loss: 0.2623, Train Accuracy: 89.67%
# Epoch 50/100 - Train Loss: 0.2608, Train Accuracy: 89.74%
# [Epoch 50] Test Loss: 0.2692, Test Accuracy: 89.26%
# Epoch 51/100 - Train Loss: 0.2586, Train Accuracy: 89.86%
# Epoch 52/100 - Train Loss: 0.2583, Train Accuracy: 89.86%
# Epoch 53/100 - Train Loss: 0.2565, Train Accuracy: 89.92%
# Epoch 54/100 - Train Loss: 0.2554, Train Accuracy: 89.98%
# Epoch 55/100 - Train Loss: 0.2543, Train Accuracy: 90.04%
# [Epoch 55] Test Loss: 0.2613, Test Accuracy: 89.61%
# Epoch 56/100 - Train Loss: 0.2523, Train Accuracy: 90.12%
# Epoch 57/100 - Train Loss: 0.2512, Train Accuracy: 90.14%
# Epoch 58/100 - Train Loss: 0.2491, Train Accuracy: 90.23%
# Epoch 59/100 - Train Loss: 0.2486, Train Accuracy: 90.23%
# Epoch 60/100 - Train Loss: 0.2470, Train Accuracy: 90.30%
# [Epoch 60] Test Loss: 0.2619, Test Accuracy: 89.48%
# Epoch 61/100 - Train Loss: 0.2460, Train Accuracy: 90.33%
# Epoch 62/100 - Train Loss: 0.2447, Train Accuracy: 90.43%
# Epoch 63/100 - Train Loss: 0.2434, Train Accuracy: 90.49%
# Epoch 64/100 - Train Loss: 0.2419, Train Accuracy: 90.49%
# Epoch 65/100 - Train Loss: 0.2412, Train Accuracy: 90.56%
# [Epoch 65] Test Loss: 0.2525, Test Accuracy: 90.01%
# Epoch 66/100 - Train Loss: 0.2393, Train Accuracy: 90.67%
# Epoch 67/100 - Train Loss: 0.2384, Train Accuracy: 90.63%
# Epoch 68/100 - Train Loss: 0.2378, Train Accuracy: 90.67%
# Epoch 69/100 - Train Loss: 0.2367, Train Accuracy: 90.73%
# Epoch 70/100 - Train Loss: 0.2360, Train Accuracy: 90.79%
# [Epoch 70] Test Loss: 0.2399, Test Accuracy: 90.57%
# Epoch 71/100 - Train Loss: 0.2344, Train Accuracy: 90.83%
# Epoch 72/100 - Train Loss: 0.2332, Train Accuracy: 90.87%
# Epoch 73/100 - Train Loss: 0.2326, Train Accuracy: 90.91%
# Epoch 74/100 - Train Loss: 0.2313, Train Accuracy: 90.95%
# Epoch 75/100 - Train Loss: 0.2307, Train Accuracy: 90.99%
# [Epoch 75] Test Loss: 0.2359, Test Accuracy: 90.71%
# Epoch 76/100 - Train Loss: 0.2297, Train Accuracy: 91.05%
# Epoch 77/100 - Train Loss: 0.2290, Train Accuracy: 91.06%
# Epoch 78/100 - Train Loss: 0.2275, Train Accuracy: 91.09%
# Epoch 79/100 - Train Loss: 0.2273, Train Accuracy: 91.11%
# Epoch 80/100 - Train Loss: 0.2262, Train Accuracy: 91.15%
# [Epoch 80] Test Loss: 0.2320, Test Accuracy: 90.87%
# Epoch 81/100 - Train Loss: 0.2250, Train Accuracy: 91.22%
# Epoch 82/100 - Train Loss: 0.2248, Train Accuracy: 91.26%
# Epoch 83/100 - Train Loss: 0.2236, Train Accuracy: 91.25%
# Epoch 84/100 - Train Loss: 0.2224, Train Accuracy: 91.35%
# Epoch 85/100 - Train Loss: 0.2218, Train Accuracy: 91.32%
# [Epoch 85] Test Loss: 0.2294, Test Accuracy: 90.97%
# Epoch 86/100 - Train Loss: 0.2206, Train Accuracy: 91.40%
# Epoch 87/100 - Train Loss: 0.2201, Train Accuracy: 91.43%
# Epoch 88/100 - Train Loss: 0.2196, Train Accuracy: 91.41%
# Epoch 89/100 - Train Loss: 0.2188, Train Accuracy: 91.46%
# Epoch 90/100 - Train Loss: 0.2179, Train Accuracy: 91.51%
# [Epoch 90] Test Loss: 0.2233, Test Accuracy: 91.17%
# Epoch 91/100 - Train Loss: 0.2168, Train Accuracy: 91.53%
# Epoch 92/100 - Train Loss: 0.2159, Train Accuracy: 91.59%
# Epoch 93/100 - Train Loss: 0.2157, Train Accuracy: 91.59%
# Epoch 94/100 - Train Loss: 0.2152, Train Accuracy: 91.57%
# Epoch 95/100 - Train Loss: 0.2146, Train Accuracy: 91.66%
# [Epoch 95] Test Loss: 0.2302, Test Accuracy: 90.90%
# Epoch 96/100 - Train Loss: 0.2139, Train Accuracy: 91.66%
# Epoch 97/100 - Train Loss: 0.2130, Train Accuracy: 91.70%
# Epoch 98/100 - Train Loss: 0.2125, Train Accuracy: 91.70%
# Epoch 99/100 - Train Loss: 0.2108, Train Accuracy: 91.82%
# Epoch 100/100 - Train Loss: 0.2111, Train Accuracy: 91.80%
# [Epoch 100] Test Loss: 0.2221, Test Accuracy: 91.23%
# [use_mask=False, reg=L1] Final Test Accuracy: 91.23%, Test Loss: 0.2221
# Run data saved to runs_Covertype/20250711_145637_act-ReLU_mask-False_thresh-0.7_reg-L1_epochs-100-Covertype
# 3350.297033071518
# Epoch 1/100 - Train Loss: 0.7011, Train Accuracy: 71.54%
# Epoch 2/100 - Train Loss: 0.5757, Train Accuracy: 75.52%
# Epoch 3/100 - Train Loss: 0.5416, Train Accuracy: 76.83%
# Epoch 4/100 - Train Loss: 0.5173, Train Accuracy: 77.82%
# Epoch 5/100 - Train Loss: 0.4980, Train Accuracy: 78.59%
# [Epoch 5] Test Loss: 0.4925, Test Accuracy: 78.93%
# Epoch 6/100 - Train Loss: 0.4822, Train Accuracy: 79.35%
# Epoch 7/100 - Train Loss: 0.4681, Train Accuracy: 80.05%
# Epoch 8/100 - Train Loss: 0.4554, Train Accuracy: 80.70%
# Epoch 9/100 - Train Loss: 0.4447, Train Accuracy: 81.23%
# Epoch 10/100 - Train Loss: 0.4349, Train Accuracy: 81.69%
# [Epoch 10] Test Loss: 0.4318, Test Accuracy: 81.98%
# Epoch 11/100 - Train Loss: 0.4265, Train Accuracy: 82.05%
# Epoch 12/100 - Train Loss: 0.4184, Train Accuracy: 82.44%
# Epoch 13/100 - Train Loss: 0.4111, Train Accuracy: 82.79%
# Epoch 14/100 - Train Loss: 0.4042, Train Accuracy: 83.09%
# Epoch 15/100 - Train Loss: 0.3984, Train Accuracy: 83.39%
# [Epoch 15] Test Loss: 0.3981, Test Accuracy: 83.36%
# Epoch 16/100 - Train Loss: 0.3928, Train Accuracy: 83.60%
# Epoch 17/100 - Train Loss: 0.3877, Train Accuracy: 83.84%
# Epoch 18/100 - Train Loss: 0.3827, Train Accuracy: 84.12%
# Epoch 19/100 - Train Loss: 0.3782, Train Accuracy: 84.30%
# Epoch 20/100 - Train Loss: 0.3742, Train Accuracy: 84.52%
# [Epoch 20] Test Loss: 0.3723, Test Accuracy: 84.72%
# Epoch 21/100 - Train Loss: 0.3696, Train Accuracy: 84.75%
# Epoch 22/100 - Train Loss: 0.3657, Train Accuracy: 84.90%
# Epoch 23/100 - Train Loss: 0.3622, Train Accuracy: 85.07%
# Epoch 24/100 - Train Loss: 0.3588, Train Accuracy: 85.22%
# Epoch 25/100 - Train Loss: 0.3556, Train Accuracy: 85.41%
# [Epoch 25] Test Loss: 0.3633, Test Accuracy: 85.18%
# Epoch 26/100 - Train Loss: 0.3527, Train Accuracy: 85.47%
# Epoch 27/100 - Train Loss: 0.3493, Train Accuracy: 85.69%
# Epoch 28/100 - Train Loss: 0.3464, Train Accuracy: 85.78%
# Epoch 29/100 - Train Loss: 0.3439, Train Accuracy: 85.90%
# Epoch 30/100 - Train Loss: 0.3406, Train Accuracy: 86.07%
# [Epoch 30] Test Loss: 0.3452, Test Accuracy: 85.90%
# Epoch 31/100 - Train Loss: 0.3384, Train Accuracy: 86.17%
# Epoch 32/100 - Train Loss: 0.3359, Train Accuracy: 86.28%
# Epoch 33/100 - Train Loss: 0.3338, Train Accuracy: 86.37%
# Epoch 34/100 - Train Loss: 0.3315, Train Accuracy: 86.48%
# Epoch 35/100 - Train Loss: 0.3294, Train Accuracy: 86.60%
# [Epoch 35] Test Loss: 0.3294, Test Accuracy: 86.64%
# Epoch 36/100 - Train Loss: 0.3274, Train Accuracy: 86.71%
# Epoch 37/100 - Train Loss: 0.3250, Train Accuracy: 86.85%
# Epoch 38/100 - Train Loss: 0.3232, Train Accuracy: 86.86%
# Epoch 39/100 - Train Loss: 0.3213, Train Accuracy: 87.00%
# Epoch 40/100 - Train Loss: 0.3197, Train Accuracy: 87.04%
# [Epoch 40] Test Loss: 0.3249, Test Accuracy: 86.83%
# Epoch 41/100 - Train Loss: 0.3175, Train Accuracy: 87.09%
# Epoch 42/100 - Train Loss: 0.3159, Train Accuracy: 87.20%
# Epoch 43/100 - Train Loss: 0.3141, Train Accuracy: 87.29%
# Epoch 44/100 - Train Loss: 0.3121, Train Accuracy: 87.35%
# Epoch 45/100 - Train Loss: 0.3109, Train Accuracy: 87.39%
# [Epoch 45] Test Loss: 0.3150, Test Accuracy: 87.26%
# Epoch 46/100 - Train Loss: 0.3084, Train Accuracy: 87.54%
# Epoch 47/100 - Train Loss: 0.3071, Train Accuracy: 87.56%
# Epoch 48/100 - Train Loss: 0.3054, Train Accuracy: 87.66%
# Epoch 49/100 - Train Loss: 0.3040, Train Accuracy: 87.71%
# Epoch 50/100 - Train Loss: 0.3027, Train Accuracy: 87.79%
# [Epoch 50] Test Loss: 0.3106, Test Accuracy: 87.45%
# Epoch 51/100 - Train Loss: 0.3012, Train Accuracy: 87.83%
# Epoch 52/100 - Train Loss: 0.2997, Train Accuracy: 87.89%
# Epoch 53/100 - Train Loss: 0.2981, Train Accuracy: 87.98%
# Epoch 54/100 - Train Loss: 0.2966, Train Accuracy: 88.07%
# Epoch 55/100 - Train Loss: 0.2957, Train Accuracy: 88.09%
# [Epoch 55] Test Loss: 0.3026, Test Accuracy: 87.82%
# Epoch 56/100 - Train Loss: 0.2939, Train Accuracy: 88.19%
# Epoch 57/100 - Train Loss: 0.2932, Train Accuracy: 88.21%
# Epoch 58/100 - Train Loss: 0.2917, Train Accuracy: 88.26%
# Epoch 59/100 - Train Loss: 0.2908, Train Accuracy: 88.29%
# Epoch 60/100 - Train Loss: 0.2894, Train Accuracy: 88.35%
# [Epoch 60] Test Loss: 0.3020, Test Accuracy: 87.71%
# Epoch 61/100 - Train Loss: 0.2886, Train Accuracy: 88.44%
# Epoch 62/100 - Train Loss: 0.2875, Train Accuracy: 88.41%
# Epoch 63/100 - Train Loss: 0.2857, Train Accuracy: 88.51%
# Epoch 64/100 - Train Loss: 0.2848, Train Accuracy: 88.58%
# Epoch 65/100 - Train Loss: 0.2840, Train Accuracy: 88.57%
# [Epoch 65] Test Loss: 0.2938, Test Accuracy: 88.14%
# Epoch 66/100 - Train Loss: 0.2830, Train Accuracy: 88.66%
# Epoch 67/100 - Train Loss: 0.2818, Train Accuracy: 88.71%
# Epoch 68/100 - Train Loss: 0.2808, Train Accuracy: 88.73%
# Epoch 69/100 - Train Loss: 0.2798, Train Accuracy: 88.76%
# Epoch 70/100 - Train Loss: 0.2794, Train Accuracy: 88.80%
# [Epoch 70] Test Loss: 0.2869, Test Accuracy: 88.50%
# Epoch 71/100 - Train Loss: 0.2779, Train Accuracy: 88.89%
# Epoch 72/100 - Train Loss: 0.2774, Train Accuracy: 88.89%
# Epoch 73/100 - Train Loss: 0.2762, Train Accuracy: 88.94%
# Epoch 74/100 - Train Loss: 0.2758, Train Accuracy: 88.97%
# Epoch 75/100 - Train Loss: 0.2745, Train Accuracy: 89.02%
# [Epoch 75] Test Loss: 0.2826, Test Accuracy: 88.75%
# Epoch 76/100 - Train Loss: 0.2737, Train Accuracy: 89.04%
# Epoch 77/100 - Train Loss: 0.2728, Train Accuracy: 89.07%
# Epoch 78/100 - Train Loss: 0.2722, Train Accuracy: 89.10%
# Epoch 79/100 - Train Loss: 0.2714, Train Accuracy: 89.15%
# Epoch 80/100 - Train Loss: 0.2708, Train Accuracy: 89.14%
# [Epoch 80] Test Loss: 0.2799, Test Accuracy: 88.83%
# Epoch 81/100 - Train Loss: 0.2695, Train Accuracy: 89.22%
# Epoch 82/100 - Train Loss: 0.2687, Train Accuracy: 89.24%
# Epoch 83/100 - Train Loss: 0.2684, Train Accuracy: 89.25%
# Epoch 84/100 - Train Loss: 0.2673, Train Accuracy: 89.30%
# Epoch 85/100 - Train Loss: 0.2668, Train Accuracy: 89.33%
# [Epoch 85] Test Loss: 0.2826, Test Accuracy: 88.61%
# Epoch 86/100 - Train Loss: 0.2664, Train Accuracy: 89.36%
# Epoch 87/100 - Train Loss: 0.2655, Train Accuracy: 89.39%
# Epoch 88/100 - Train Loss: 0.2643, Train Accuracy: 89.47%
# Epoch 89/100 - Train Loss: 0.2634, Train Accuracy: 89.52%
# Epoch 90/100 - Train Loss: 0.2627, Train Accuracy: 89.54%
# [Epoch 90] Test Loss: 0.2810, Test Accuracy: 88.90%
# Epoch 91/100 - Train Loss: 0.2626, Train Accuracy: 89.56%
# Epoch 92/100 - Train Loss: 0.2615, Train Accuracy: 89.56%
# Epoch 93/100 - Train Loss: 0.2610, Train Accuracy: 89.59%
# Epoch 94/100 - Train Loss: 0.2606, Train Accuracy: 89.58%
# Epoch 95/100 - Train Loss: 0.2594, Train Accuracy: 89.64%
# [Epoch 95] Test Loss: 0.2787, Test Accuracy: 88.83%
# Epoch 96/100 - Train Loss: 0.2592, Train Accuracy: 89.64%
# Epoch 97/100 - Train Loss: 0.2583, Train Accuracy: 89.69%
# Epoch 98/100 - Train Loss: 0.2575, Train Accuracy: 89.70%
# Epoch 99/100 - Train Loss: 0.2568, Train Accuracy: 89.77%
# Epoch 100/100 - Train Loss: 0.2567, Train Accuracy: 89.76%
# [Epoch 100] Test Loss: 0.2668, Test Accuracy: 89.38%
# [use_mask=True, reg=None] Final Test Accuracy: 89.38%, Test Loss: 0.2668
# Run data saved to runs_Covertype/20250711_155000_act-ReLU_mask-True_thresh-0.11_reg-None_epochs-100-Covertype
# 3203.549150466919
# Epoch 1/100 - Train Loss: 0.7351, Train Accuracy: 70.53%
# Epoch 2/100 - Train Loss: 0.5993, Train Accuracy: 74.52%
# Epoch 3/100 - Train Loss: 0.5686, Train Accuracy: 75.71%
# Epoch 4/100 - Train Loss: 0.5466, Train Accuracy: 76.64%
# Epoch 5/100 - Train Loss: 0.5302, Train Accuracy: 77.33%
# [Epoch 5] Test Loss: 0.5252, Test Accuracy: 77.50%
# Epoch 6/100 - Train Loss: 0.5171, Train Accuracy: 77.89%
# Epoch 7/100 - Train Loss: 0.5054, Train Accuracy: 78.38%
# Epoch 8/100 - Train Loss: 0.4958, Train Accuracy: 78.82%
# Epoch 9/100 - Train Loss: 0.4866, Train Accuracy: 79.24%
# Epoch 10/100 - Train Loss: 0.4788, Train Accuracy: 79.60%
# [Epoch 10] Test Loss: 0.4777, Test Accuracy: 79.71%
# Epoch 11/100 - Train Loss: 0.4711, Train Accuracy: 80.01%
# Epoch 12/100 - Train Loss: 0.4642, Train Accuracy: 80.36%
# Epoch 13/100 - Train Loss: 0.4582, Train Accuracy: 80.65%
# Epoch 14/100 - Train Loss: 0.4525, Train Accuracy: 80.95%
# Epoch 15/100 - Train Loss: 0.4473, Train Accuracy: 81.17%
# [Epoch 15] Test Loss: 0.4478, Test Accuracy: 81.17%
# Epoch 16/100 - Train Loss: 0.4427, Train Accuracy: 81.45%
# Epoch 17/100 - Train Loss: 0.4385, Train Accuracy: 81.59%
# Epoch 18/100 - Train Loss: 0.4342, Train Accuracy: 81.85%
# Epoch 19/100 - Train Loss: 0.4296, Train Accuracy: 82.05%
# Epoch 20/100 - Train Loss: 0.4258, Train Accuracy: 82.15%
# [Epoch 20] Test Loss: 0.4334, Test Accuracy: 81.70%
# Epoch 21/100 - Train Loss: 0.4221, Train Accuracy: 82.34%
# Epoch 22/100 - Train Loss: 0.4185, Train Accuracy: 82.45%
# Epoch 23/100 - Train Loss: 0.4154, Train Accuracy: 82.61%
# Epoch 24/100 - Train Loss: 0.4117, Train Accuracy: 82.75%
# Epoch 25/100 - Train Loss: 0.4090, Train Accuracy: 82.86%
# [Epoch 25] Test Loss: 0.4108, Test Accuracy: 82.87%
# Epoch 26/100 - Train Loss: 0.4063, Train Accuracy: 82.99%
# Epoch 27/100 - Train Loss: 0.4037, Train Accuracy: 83.15%
# Epoch 28/100 - Train Loss: 0.4013, Train Accuracy: 83.22%
# Epoch 29/100 - Train Loss: 0.3993, Train Accuracy: 83.28%
# Epoch 30/100 - Train Loss: 0.3963, Train Accuracy: 83.43%
# [Epoch 30] Test Loss: 0.3999, Test Accuracy: 83.37%
# Epoch 31/100 - Train Loss: 0.3945, Train Accuracy: 83.52%
# Epoch 32/100 - Train Loss: 0.3928, Train Accuracy: 83.55%
# Epoch 33/100 - Train Loss: 0.3903, Train Accuracy: 83.61%
# Epoch 34/100 - Train Loss: 0.3879, Train Accuracy: 83.76%
# Epoch 35/100 - Train Loss: 0.3861, Train Accuracy: 83.88%
# [Epoch 35] Test Loss: 0.3895, Test Accuracy: 83.72%
# Epoch 36/100 - Train Loss: 0.3838, Train Accuracy: 83.97%
# Epoch 37/100 - Train Loss: 0.3820, Train Accuracy: 84.05%
# Epoch 38/100 - Train Loss: 0.3804, Train Accuracy: 84.15%
# Epoch 39/100 - Train Loss: 0.3788, Train Accuracy: 84.24%
# Epoch 40/100 - Train Loss: 0.3775, Train Accuracy: 84.28%
# [Epoch 40] Test Loss: 0.3830, Test Accuracy: 83.92%
# Epoch 41/100 - Train Loss: 0.3758, Train Accuracy: 84.33%
# Epoch 42/100 - Train Loss: 0.3739, Train Accuracy: 84.41%
# Epoch 43/100 - Train Loss: 0.3727, Train Accuracy: 84.49%
# Epoch 44/100 - Train Loss: 0.3716, Train Accuracy: 84.50%
# Epoch 45/100 - Train Loss: 0.3695, Train Accuracy: 84.60%
# [Epoch 45] Test Loss: 0.3789, Test Accuracy: 84.00%
# Epoch 46/100 - Train Loss: 0.3677, Train Accuracy: 84.65%
# Epoch 47/100 - Train Loss: 0.3669, Train Accuracy: 84.75%
# Epoch 48/100 - Train Loss: 0.3652, Train Accuracy: 84.82%
# Epoch 49/100 - Train Loss: 0.3639, Train Accuracy: 84.85%
# Epoch 50/100 - Train Loss: 0.3629, Train Accuracy: 84.91%
# [Epoch 50] Test Loss: 0.3673, Test Accuracy: 84.75%
# Epoch 51/100 - Train Loss: 0.3614, Train Accuracy: 84.97%
# Epoch 52/100 - Train Loss: 0.3602, Train Accuracy: 85.01%
# Epoch 53/100 - Train Loss: 0.3593, Train Accuracy: 85.08%
# Epoch 54/100 - Train Loss: 0.3580, Train Accuracy: 85.11%
# Epoch 55/100 - Train Loss: 0.3567, Train Accuracy: 85.22%
# [Epoch 55] Test Loss: 0.3613, Test Accuracy: 84.92%
# Epoch 56/100 - Train Loss: 0.3558, Train Accuracy: 85.21%
# Epoch 57/100 - Train Loss: 0.3551, Train Accuracy: 85.23%
# Epoch 58/100 - Train Loss: 0.3539, Train Accuracy: 85.30%
# Epoch 59/100 - Train Loss: 0.3530, Train Accuracy: 85.32%
# Epoch 60/100 - Train Loss: 0.3517, Train Accuracy: 85.39%
# [Epoch 60] Test Loss: 0.3594, Test Accuracy: 85.13%
# Epoch 61/100 - Train Loss: 0.3507, Train Accuracy: 85.46%
# Epoch 62/100 - Train Loss: 0.3497, Train Accuracy: 85.53%
# Epoch 63/100 - Train Loss: 0.3485, Train Accuracy: 85.55%
# Epoch 64/100 - Train Loss: 0.3474, Train Accuracy: 85.59%
# Epoch 65/100 - Train Loss: 0.3465, Train Accuracy: 85.66%
# [Epoch 65] Test Loss: 0.3535, Test Accuracy: 85.44%
# Epoch 66/100 - Train Loss: 0.3456, Train Accuracy: 85.69%
# Epoch 67/100 - Train Loss: 0.3450, Train Accuracy: 85.72%
# Epoch 68/100 - Train Loss: 0.3443, Train Accuracy: 85.78%
# Epoch 69/100 - Train Loss: 0.3430, Train Accuracy: 85.84%
# Epoch 70/100 - Train Loss: 0.3421, Train Accuracy: 85.87%
# [Epoch 70] Test Loss: 0.3492, Test Accuracy: 85.65%
# Epoch 71/100 - Train Loss: 0.3416, Train Accuracy: 85.90%
# Epoch 72/100 - Train Loss: 0.3405, Train Accuracy: 85.99%
# Epoch 73/100 - Train Loss: 0.3398, Train Accuracy: 85.98%
# Epoch 74/100 - Train Loss: 0.3389, Train Accuracy: 86.08%
# Epoch 75/100 - Train Loss: 0.3384, Train Accuracy: 86.05%
# [Epoch 75] Test Loss: 0.3458, Test Accuracy: 85.92%
# Epoch 76/100 - Train Loss: 0.3377, Train Accuracy: 86.13%
# Epoch 77/100 - Train Loss: 0.3375, Train Accuracy: 86.12%
# Epoch 78/100 - Train Loss: 0.3365, Train Accuracy: 86.11%
# Epoch 79/100 - Train Loss: 0.3357, Train Accuracy: 86.20%
# Epoch 80/100 - Train Loss: 0.3356, Train Accuracy: 86.19%
# [Epoch 80] Test Loss: 0.3421, Test Accuracy: 85.94%
# Epoch 81/100 - Train Loss: 0.3345, Train Accuracy: 86.28%
# Epoch 82/100 - Train Loss: 0.3339, Train Accuracy: 86.27%
# Epoch 83/100 - Train Loss: 0.3328, Train Accuracy: 86.30%
# Epoch 84/100 - Train Loss: 0.3325, Train Accuracy: 86.30%
# Epoch 85/100 - Train Loss: 0.3316, Train Accuracy: 86.38%
# [Epoch 85] Test Loss: 0.3398, Test Accuracy: 86.14%
# Epoch 86/100 - Train Loss: 0.3310, Train Accuracy: 86.46%
# Epoch 87/100 - Train Loss: 0.3307, Train Accuracy: 86.48%
# Epoch 88/100 - Train Loss: 0.3298, Train Accuracy: 86.51%
# Epoch 89/100 - Train Loss: 0.3292, Train Accuracy: 86.55%
# Epoch 90/100 - Train Loss: 0.3284, Train Accuracy: 86.53%
# [Epoch 90] Test Loss: 0.3393, Test Accuracy: 86.11%
# Epoch 91/100 - Train Loss: 0.3282, Train Accuracy: 86.61%
# Epoch 92/100 - Train Loss: 0.3281, Train Accuracy: 86.57%
# Epoch 93/100 - Train Loss: 0.3275, Train Accuracy: 86.60%
# Epoch 94/100 - Train Loss: 0.3268, Train Accuracy: 86.67%
# Epoch 95/100 - Train Loss: 0.3261, Train Accuracy: 86.69%
# [Epoch 95] Test Loss: 0.3342, Test Accuracy: 86.35%
# Epoch 96/100 - Train Loss: 0.3253, Train Accuracy: 86.71%
# Epoch 97/100 - Train Loss: 0.3251, Train Accuracy: 86.73%
# Epoch 98/100 - Train Loss: 0.3252, Train Accuracy: 86.72%
# Epoch 99/100 - Train Loss: 0.3245, Train Accuracy: 86.74%
# Epoch 100/100 - Train Loss: 0.3239, Train Accuracy: 86.81%
# [Epoch 100] Test Loss: 0.3311, Test Accuracy: 86.62%
# [use_mask=True, reg=None] Final Test Accuracy: 86.62%, Test Loss: 0.3311
# Run data saved to runs_Covertype/20250711_164144_act-ReLU_mask-True_thresh-0.69_reg-None_epochs-100-Covertype
# 3103.9013533592224
# Epoch 1/100 - Train Loss: 0.8290, Train Accuracy: 66.74%
# Epoch 2/100 - Train Loss: 0.6506, Train Accuracy: 72.76%
# Epoch 3/100 - Train Loss: 0.6230, Train Accuracy: 73.51%
# Epoch 4/100 - Train Loss: 0.6069, Train Accuracy: 73.95%
# Epoch 5/100 - Train Loss: 0.5959, Train Accuracy: 74.27%
# [Epoch 5] Test Loss: 0.5938, Test Accuracy: 74.40%
# Epoch 6/100 - Train Loss: 0.5867, Train Accuracy: 74.58%
# Epoch 7/100 - Train Loss: 0.5794, Train Accuracy: 74.92%
# Epoch 8/100 - Train Loss: 0.5728, Train Accuracy: 75.24%
# Epoch 9/100 - Train Loss: 0.5663, Train Accuracy: 75.53%
# Epoch 10/100 - Train Loss: 0.5605, Train Accuracy: 75.82%
# [Epoch 10] Test Loss: 0.5618, Test Accuracy: 75.89%
# Epoch 11/100 - Train Loss: 0.5554, Train Accuracy: 76.03%
# Epoch 12/100 - Train Loss: 0.5506, Train Accuracy: 76.24%
# Epoch 13/100 - Train Loss: 0.5463, Train Accuracy: 76.44%
# Epoch 14/100 - Train Loss: 0.5423, Train Accuracy: 76.65%
# Epoch 15/100 - Train Loss: 0.5389, Train Accuracy: 76.87%
# [Epoch 15] Test Loss: 0.5409, Test Accuracy: 76.90%
# Epoch 16/100 - Train Loss: 0.5368, Train Accuracy: 77.00%
# Epoch 17/100 - Train Loss: 0.5334, Train Accuracy: 77.15%
# Epoch 18/100 - Train Loss: 0.5305, Train Accuracy: 77.32%
# Epoch 19/100 - Train Loss: 0.5278, Train Accuracy: 77.41%
# Epoch 20/100 - Train Loss: 0.5256, Train Accuracy: 77.57%
# [Epoch 20] Test Loss: 0.5277, Test Accuracy: 77.62%
# Epoch 21/100 - Train Loss: 0.5229, Train Accuracy: 77.67%
# Epoch 22/100 - Train Loss: 0.5207, Train Accuracy: 77.76%
# Epoch 23/100 - Train Loss: 0.5186, Train Accuracy: 77.84%
# Epoch 24/100 - Train Loss: 0.5174, Train Accuracy: 77.90%
# Epoch 25/100 - Train Loss: 0.5156, Train Accuracy: 77.93%
# [Epoch 25] Test Loss: 0.5185, Test Accuracy: 77.98%
# Epoch 26/100 - Train Loss: 0.5134, Train Accuracy: 78.07%
# Epoch 27/100 - Train Loss: 0.5115, Train Accuracy: 78.19%
# Epoch 28/100 - Train Loss: 0.5097, Train Accuracy: 78.24%
# Epoch 29/100 - Train Loss: 0.5081, Train Accuracy: 78.32%
# Epoch 30/100 - Train Loss: 0.5065, Train Accuracy: 78.40%
# [Epoch 30] Test Loss: 0.5093, Test Accuracy: 78.45%
# Epoch 31/100 - Train Loss: 0.5050, Train Accuracy: 78.48%
# Epoch 32/100 - Train Loss: 0.5037, Train Accuracy: 78.53%
# Epoch 33/100 - Train Loss: 0.5020, Train Accuracy: 78.60%
# Epoch 34/100 - Train Loss: 0.5007, Train Accuracy: 78.65%
# Epoch 35/100 - Train Loss: 0.4993, Train Accuracy: 78.73%
# [Epoch 35] Test Loss: 0.5030, Test Accuracy: 78.62%
# Epoch 36/100 - Train Loss: 0.4982, Train Accuracy: 78.78%
# Epoch 37/100 - Train Loss: 0.4970, Train Accuracy: 78.84%
# Epoch 38/100 - Train Loss: 0.4959, Train Accuracy: 78.89%
# Epoch 39/100 - Train Loss: 0.4948, Train Accuracy: 78.92%
# Epoch 40/100 - Train Loss: 0.4937, Train Accuracy: 78.94%
# [Epoch 40] Test Loss: 0.4974, Test Accuracy: 79.02%
# Epoch 41/100 - Train Loss: 0.4928, Train Accuracy: 78.95%
# Epoch 42/100 - Train Loss: 0.4917, Train Accuracy: 79.03%
# Epoch 43/100 - Train Loss: 0.4908, Train Accuracy: 79.06%
# Epoch 44/100 - Train Loss: 0.4898, Train Accuracy: 79.11%
# Epoch 45/100 - Train Loss: 0.4890, Train Accuracy: 79.13%
# [Epoch 45] Test Loss: 0.4927, Test Accuracy: 79.22%
# Epoch 46/100 - Train Loss: 0.4882, Train Accuracy: 79.18%
# Epoch 47/100 - Train Loss: 0.4873, Train Accuracy: 79.23%
# Epoch 48/100 - Train Loss: 0.4865, Train Accuracy: 79.26%
# Epoch 49/100 - Train Loss: 0.4856, Train Accuracy: 79.34%
# Epoch 50/100 - Train Loss: 0.4847, Train Accuracy: 79.34%
# [Epoch 50] Test Loss: 0.4884, Test Accuracy: 79.39%
# Epoch 51/100 - Train Loss: 0.4838, Train Accuracy: 79.38%
# Epoch 52/100 - Train Loss: 0.4831, Train Accuracy: 79.42%
# Epoch 53/100 - Train Loss: 0.4823, Train Accuracy: 79.43%
# Epoch 54/100 - Train Loss: 0.4822, Train Accuracy: 79.42%
# Epoch 55/100 - Train Loss: 0.4823, Train Accuracy: 79.43%
# [Epoch 55] Test Loss: 0.4858, Test Accuracy: 79.49%
# Epoch 56/100 - Train Loss: 0.4808, Train Accuracy: 79.51%
# Epoch 57/100 - Train Loss: 0.4801, Train Accuracy: 79.54%
# Epoch 58/100 - Train Loss: 0.4790, Train Accuracy: 79.56%
# Epoch 59/100 - Train Loss: 0.4783, Train Accuracy: 79.60%
# Epoch 60/100 - Train Loss: 0.4783, Train Accuracy: 79.61%
# [Epoch 60] Test Loss: 0.4821, Test Accuracy: 79.71%
# Epoch 61/100 - Train Loss: 0.4783, Train Accuracy: 79.60%
# Epoch 62/100 - Train Loss: 0.4768, Train Accuracy: 79.69%
# Epoch 63/100 - Train Loss: 0.4759, Train Accuracy: 79.72%
# Epoch 64/100 - Train Loss: 0.4748, Train Accuracy: 79.73%
# Epoch 65/100 - Train Loss: 0.4739, Train Accuracy: 79.80%
# [Epoch 65] Test Loss: 0.4778, Test Accuracy: 79.87%
# Epoch 66/100 - Train Loss: 0.4733, Train Accuracy: 79.81%
# Epoch 67/100 - Train Loss: 0.4725, Train Accuracy: 79.86%
# Epoch 68/100 - Train Loss: 0.4719, Train Accuracy: 79.89%
# Epoch 69/100 - Train Loss: 0.4712, Train Accuracy: 79.93%
# Epoch 70/100 - Train Loss: 0.4708, Train Accuracy: 79.92%
# [Epoch 70] Test Loss: 0.4769, Test Accuracy: 79.81%
# Epoch 71/100 - Train Loss: 0.4707, Train Accuracy: 79.94%
# Epoch 72/100 - Train Loss: 0.4706, Train Accuracy: 79.90%
# Epoch 73/100 - Train Loss: 0.4695, Train Accuracy: 79.97%
# Epoch 74/100 - Train Loss: 0.4700, Train Accuracy: 79.95%
# Epoch 75/100 - Train Loss: 0.4686, Train Accuracy: 79.95%
# [Epoch 75] Test Loss: 0.4727, Test Accuracy: 79.94%
# Epoch 76/100 - Train Loss: 0.4678, Train Accuracy: 80.01%
# Epoch 77/100 - Train Loss: 0.4675, Train Accuracy: 80.06%
# Epoch 78/100 - Train Loss: 0.4667, Train Accuracy: 80.09%
# Epoch 79/100 - Train Loss: 0.4660, Train Accuracy: 80.14%
# Epoch 80/100 - Train Loss: 0.4657, Train Accuracy: 80.15%
# [Epoch 80] Test Loss: 0.4702, Test Accuracy: 80.17%
# Epoch 81/100 - Train Loss: 0.4660, Train Accuracy: 80.12%
# Epoch 82/100 - Train Loss: 0.4661, Train Accuracy: 80.15%
# Epoch 83/100 - Train Loss: 0.4649, Train Accuracy: 80.23%
# Epoch 84/100 - Train Loss: 0.4645, Train Accuracy: 80.23%
# Epoch 85/100 - Train Loss: 0.4652, Train Accuracy: 80.19%
# [Epoch 85] Test Loss: 0.4686, Test Accuracy: 80.30%
# Epoch 86/100 - Train Loss: 0.4638, Train Accuracy: 80.25%
# Epoch 87/100 - Train Loss: 0.4633, Train Accuracy: 80.28%
# Epoch 88/100 - Train Loss: 0.4630, Train Accuracy: 80.31%
# Epoch 89/100 - Train Loss: 0.4619, Train Accuracy: 80.36%
# Epoch 90/100 - Train Loss: 0.4613, Train Accuracy: 80.41%
# [Epoch 90] Test Loss: 0.4654, Test Accuracy: 80.45%
# Epoch 91/100 - Train Loss: 0.4608, Train Accuracy: 80.43%
# Epoch 92/100 - Train Loss: 0.4603, Train Accuracy: 80.49%
# Epoch 93/100 - Train Loss: 0.4596, Train Accuracy: 80.54%
# Epoch 94/100 - Train Loss: 0.4590, Train Accuracy: 80.55%
# Epoch 95/100 - Train Loss: 0.4591, Train Accuracy: 80.57%
# [Epoch 95] Test Loss: 0.4632, Test Accuracy: 80.60%
# Epoch 96/100 - Train Loss: 0.4582, Train Accuracy: 80.62%
# Epoch 97/100 - Train Loss: 0.4580, Train Accuracy: 80.60%
# Epoch 98/100 - Train Loss: 0.4579, Train Accuracy: 80.60%
# Epoch 99/100 - Train Loss: 0.4574, Train Accuracy: 80.60%
# Epoch 100/100 - Train Loss: 0.4568, Train Accuracy: 80.65%
# [Epoch 100] Test Loss: 0.4617, Test Accuracy: 80.73%
# [use_mask=True, reg=None] Final Test Accuracy: 80.73%, Test Loss: 0.4617
# Run data saved to runs_Covertype/20250711_173232_act-ReLU_mask-True_thresh-1.39_reg-None_epochs-100-Covertype
# 3048.0609092712402
# Epoch 1/100 - Train Loss: 1.4027, Train Accuracy: 49.61%
# Epoch 2/100 - Train Loss: 1.0245, Train Accuracy: 61.53%
# Epoch 3/100 - Train Loss: 0.9294, Train Accuracy: 64.84%
# Epoch 4/100 - Train Loss: 0.8841, Train Accuracy: 68.43%
# Epoch 5/100 - Train Loss: 0.8584, Train Accuracy: 69.06%
# [Epoch 5] Test Loss: 0.8517, Test Accuracy: 69.04%
# Epoch 6/100 - Train Loss: 0.8423, Train Accuracy: 69.40%
# Epoch 7/100 - Train Loss: 0.8315, Train Accuracy: 69.71%
# Epoch 8/100 - Train Loss: 0.8246, Train Accuracy: 69.99%
# Epoch 9/100 - Train Loss: 0.8204, Train Accuracy: 70.04%
# Epoch 10/100 - Train Loss: 0.8175, Train Accuracy: 70.07%
# [Epoch 10] Test Loss: 0.8193, Test Accuracy: 70.00%
# Epoch 11/100 - Train Loss: 0.8157, Train Accuracy: 70.04%
# Epoch 12/100 - Train Loss: 0.8138, Train Accuracy: 70.02%
# Epoch 13/100 - Train Loss: 0.8123, Train Accuracy: 70.02%
# Epoch 14/100 - Train Loss: 0.8110, Train Accuracy: 70.01%
# Epoch 15/100 - Train Loss: 0.8098, Train Accuracy: 70.02%
# [Epoch 15] Test Loss: 0.8121, Test Accuracy: 69.92%
# Epoch 16/100 - Train Loss: 0.8088, Train Accuracy: 70.02%
# Epoch 17/100 - Train Loss: 0.8079, Train Accuracy: 70.01%
# Epoch 18/100 - Train Loss: 0.8071, Train Accuracy: 70.01%
# Epoch 19/100 - Train Loss: 0.8065, Train Accuracy: 70.02%
# Epoch 20/100 - Train Loss: 0.8058, Train Accuracy: 70.02%
# [Epoch 20] Test Loss: 0.8083, Test Accuracy: 69.96%
# Epoch 21/100 - Train Loss: 0.8053, Train Accuracy: 70.02%
# Epoch 22/100 - Train Loss: 0.8048, Train Accuracy: 70.04%
# Epoch 23/100 - Train Loss: 0.8044, Train Accuracy: 70.02%
# Epoch 24/100 - Train Loss: 0.8040, Train Accuracy: 70.03%
# Epoch 25/100 - Train Loss: 0.8036, Train Accuracy: 70.06%
# [Epoch 25] Test Loss: 0.8061, Test Accuracy: 69.97%
# Epoch 26/100 - Train Loss: 0.8033, Train Accuracy: 70.05%
# Epoch 27/100 - Train Loss: 0.8030, Train Accuracy: 70.04%
# Epoch 28/100 - Train Loss: 0.8027, Train Accuracy: 70.05%
# Epoch 29/100 - Train Loss: 0.8025, Train Accuracy: 70.06%
# Epoch 30/100 - Train Loss: 0.8023, Train Accuracy: 70.04%
# [Epoch 30] Test Loss: 0.8047, Test Accuracy: 69.94%
# Epoch 31/100 - Train Loss: 0.8020, Train Accuracy: 70.01%
# Epoch 32/100 - Train Loss: 0.8017, Train Accuracy: 70.02%
# Epoch 33/100 - Train Loss: 0.8015, Train Accuracy: 70.02%
# Epoch 34/100 - Train Loss: 0.8013, Train Accuracy: 70.02%
# Epoch 35/100 - Train Loss: 0.8013, Train Accuracy: 70.05%
# [Epoch 35] Test Loss: 0.8038, Test Accuracy: 69.98%
# Epoch 36/100 - Train Loss: 0.8011, Train Accuracy: 70.04%
# Epoch 37/100 - Train Loss: 0.8010, Train Accuracy: 70.05%
# Epoch 38/100 - Train Loss: 0.8008, Train Accuracy: 70.04%
# Epoch 39/100 - Train Loss: 0.8007, Train Accuracy: 69.99%
# Epoch 40/100 - Train Loss: 0.8006, Train Accuracy: 69.98%
# [Epoch 40] Test Loss: 0.8032, Test Accuracy: 69.94%
# Epoch 41/100 - Train Loss: 0.8005, Train Accuracy: 69.99%
# Epoch 42/100 - Train Loss: 0.8004, Train Accuracy: 70.01%
# Epoch 43/100 - Train Loss: 0.8002, Train Accuracy: 69.99%
# Epoch 44/100 - Train Loss: 0.8004, Train Accuracy: 69.98%
# Epoch 45/100 - Train Loss: 0.8003, Train Accuracy: 69.99%
# [Epoch 45] Test Loss: 0.8027, Test Accuracy: 69.98%
# Epoch 46/100 - Train Loss: 0.8001, Train Accuracy: 69.99%
# Epoch 47/100 - Train Loss: 0.8001, Train Accuracy: 70.00%
# Epoch 48/100 - Train Loss: 0.7999, Train Accuracy: 69.97%
# Epoch 49/100 - Train Loss: 0.7998, Train Accuracy: 69.99%
# Epoch 50/100 - Train Loss: 0.7997, Train Accuracy: 69.99%
# [Epoch 50] Test Loss: 0.8021, Test Accuracy: 69.94%
# Epoch 51/100 - Train Loss: 0.7996, Train Accuracy: 69.97%
# Epoch 52/100 - Train Loss: 0.7995, Train Accuracy: 69.96%
# Epoch 53/100 - Train Loss: 0.7993, Train Accuracy: 69.96%
# Epoch 54/100 - Train Loss: 0.7991, Train Accuracy: 69.96%
# Epoch 55/100 - Train Loss: 0.7991, Train Accuracy: 69.98%
# [Epoch 55] Test Loss: 0.8016, Test Accuracy: 69.89%
# Epoch 56/100 - Train Loss: 0.7990, Train Accuracy: 69.97%
# Epoch 57/100 - Train Loss: 0.7988, Train Accuracy: 69.98%
# Epoch 58/100 - Train Loss: 0.7987, Train Accuracy: 69.95%
# Epoch 59/100 - Train Loss: 0.7985, Train Accuracy: 69.96%
# Epoch 60/100 - Train Loss: 0.7984, Train Accuracy: 69.96%
# [Epoch 60] Test Loss: 0.8007, Test Accuracy: 69.92%
# Epoch 61/100 - Train Loss: 0.7983, Train Accuracy: 69.95%
# Epoch 62/100 - Train Loss: 0.7981, Train Accuracy: 69.97%
# Epoch 63/100 - Train Loss: 0.7981, Train Accuracy: 69.95%
# Epoch 64/100 - Train Loss: 0.7979, Train Accuracy: 69.96%
# Epoch 65/100 - Train Loss: 0.7982, Train Accuracy: 69.95%
# [Epoch 65] Test Loss: 0.8010, Test Accuracy: 69.91%
# Epoch 66/100 - Train Loss: 0.7984, Train Accuracy: 69.93%
# Epoch 67/100 - Train Loss: 0.8048, Train Accuracy: 69.60%
# Epoch 68/100 - Train Loss: 0.8047, Train Accuracy: 69.67%
# Epoch 69/100 - Train Loss: 0.8041, Train Accuracy: 69.74%
# Epoch 70/100 - Train Loss: 0.8037, Train Accuracy: 69.77%
# [Epoch 70] Test Loss: 0.8059, Test Accuracy: 69.76%
# Epoch 71/100 - Train Loss: 0.8035, Train Accuracy: 69.80%
# Epoch 72/100 - Train Loss: 0.8032, Train Accuracy: 69.85%
# Epoch 73/100 - Train Loss: 0.8030, Train Accuracy: 69.86%
# Epoch 74/100 - Train Loss: 0.8028, Train Accuracy: 69.89%
# Epoch 75/100 - Train Loss: 0.8026, Train Accuracy: 69.91%
# [Epoch 75] Test Loss: 0.8049, Test Accuracy: 69.80%
# Epoch 76/100 - Train Loss: 0.8024, Train Accuracy: 69.93%
# Epoch 77/100 - Train Loss: 0.8023, Train Accuracy: 69.92%
# Epoch 78/100 - Train Loss: 0.8022, Train Accuracy: 69.95%
# Epoch 79/100 - Train Loss: 0.8020, Train Accuracy: 69.95%
# Epoch 80/100 - Train Loss: 0.8016, Train Accuracy: 69.97%
# [Epoch 80] Test Loss: 0.8027, Test Accuracy: 69.98%
# Epoch 81/100 - Train Loss: 0.8003, Train Accuracy: 70.06%
# Epoch 82/100 - Train Loss: 0.8004, Train Accuracy: 70.02%
# Epoch 83/100 - Train Loss: 0.8001, Train Accuracy: 70.04%
# Epoch 84/100 - Train Loss: 0.8001, Train Accuracy: 70.04%
# Epoch 85/100 - Train Loss: 0.8000, Train Accuracy: 70.05%
# [Epoch 85] Test Loss: 0.8023, Test Accuracy: 70.00%
# Epoch 86/100 - Train Loss: 0.7999, Train Accuracy: 70.05%
# Epoch 87/100 - Train Loss: 0.7998, Train Accuracy: 70.05%
# Epoch 88/100 - Train Loss: 0.7997, Train Accuracy: 70.03%
# Epoch 89/100 - Train Loss: 0.7996, Train Accuracy: 70.07%
# Epoch 90/100 - Train Loss: 0.7996, Train Accuracy: 70.04%
# [Epoch 90] Test Loss: 0.8020, Test Accuracy: 70.01%
# Epoch 91/100 - Train Loss: 0.7995, Train Accuracy: 70.04%
# Epoch 92/100 - Train Loss: 0.7993, Train Accuracy: 70.04%
# Epoch 93/100 - Train Loss: 0.7992, Train Accuracy: 70.06%
# Epoch 94/100 - Train Loss: 0.7992, Train Accuracy: 70.07%
# Epoch 95/100 - Train Loss: 0.7991, Train Accuracy: 70.05%
# [Epoch 95] Test Loss: 0.8014, Test Accuracy: 69.95%
# Epoch 96/100 - Train Loss: 0.7990, Train Accuracy: 70.06%
# Epoch 97/100 - Train Loss: 0.7989, Train Accuracy: 70.06%
# Epoch 98/100 - Train Loss: 0.7988, Train Accuracy: 70.05%
# Epoch 99/100 - Train Loss: 0.7987, Train Accuracy: 70.06%
# Epoch 100/100 - Train Loss: 0.7986, Train Accuracy: 70.06%
# [Epoch 100] Test Loss: 0.8010, Test Accuracy: 69.91%
# [use_mask=True, reg=None] Final Test Accuracy: 69.91%, Test Loss: 0.8010
# Run data saved to runs_Covertype/20250711_182300_act-ReLU_mask-True_thresh-2.3_reg-None_epochs-100-Covertype
# 3027.668358564377
# 262.22462272644043

# %%
all_entropies = {}
for label, the_model in model_results.items():
    entropies = []
    for name, layer in the_model.named_modules():
        if isinstance(layer, (MaskedLinear)):
            entropies.append(layer.entropy.cpu().item())
    all_entropies[label] = entropies

all_entropies
# Out:
# {'ReLU_NoMask_L1': [8.590479850769043,
#   9.532807350158691,
#   7.921241760253906,
#   4.4194183349609375],
#  'ReLU_Mask_NoReg_t1': [8.5008544921875,
#   8.870198249816895,
#   7.546030521392822,
#   3.9323408603668213],
#  'ReLU_Mask_NoReg_t3': [7.8517303466796875,
#   7.93472957611084,
#   6.367067337036133,
#   4.057591438293457],
#  'ReLU_Mask_NoReg_t4': [7.004841327667236,
#   5.637639045715332,
#   5.149396896362305,
#   3.1567084789276123],
#  'ReLU_Mask_NoReg_t5': [4.524859428405762,
#   4.244677543640137,
#   3.083719253540039,
#   1.7493162155151367]}

# %%
# Ensure plot directory exists
plot_dir = "runs_"+notebook_name+"/"+str(datetime.now().strftime("%Y%m%d_%H%M%S"))+"_plots"
os.makedirs(plot_dir, exist_ok=True)

# Plotting layer-wise entropy
plt.figure(figsize=(10, 6))
for label, entropies in all_entropies.items():
    plt.plot(range(1, len(entropies)+1), entropies, label=label)
plt.xlabel('Layer Index')
plt.ylabel('Entropy')
plt.title('Layer-wise Entropy across Model Variants')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{plot_dir}/Entropy.png")
plt.show()

# Test accuracy
plt.figure()
for label, accs in test_accs.items():
    plt.plot(range(5, 5 * len(accs) + 1, 5), accs, label=label)
plt.title("Test accuracy")
plt.ylabel('Test Accuracy')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Test_Accuracy.png")
plt.show()

# Test loss
plt.figure()
for label, loss in test_losses.items():
    plt.plot(range(5, 5 * len(accs) + 1, 5), loss, label=label)
plt.title("Test loss")
plt.ylabel('Test loss')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Test_loss.png")
plt.show()

# Speed
plt.figure()
plt.bar(times.keys(), times.values(), color='skyblue')
plt.ylabel('Speed')
plt.title('Final Speed across Model Variants')
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(f"{plot_dir}/Speed.png")
plt.show()

# Train accuracy
plt.figure()
for label, accs in train_accs.items():
    plt.plot(range(1, len(accs)+1), accs, label=label)
plt.title("Train accuracy")
plt.ylabel('Train Accuracy')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Train_Accuracy.png")
plt.show()

# Train loss
plt.figure()
for label, loss in train_losses.items():
    plt.plot(range(1, len(loss)+1), loss, label=label)
plt.title("Train loss")
plt.ylabel('Train loss')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Train_loss.png")
plt.show()

# %%
def get_squared_weight_matrix(layer):
    # # For Conv layers, flatten input/output dimensions
    # if isinstance(layer, MaskedConv):
    #     # Shape: [out_channels, in_channels, kH, kW]
    #     M = layer.weight.view(layer.out_channels, -1)  # [out_c, in_c * kH * kW]
    if isinstance(layer, MaskedLinear):
        # Shape: [out_features, in_features]
        M = layer.weight
        W = torch.pow(10,-layer.wval(layer.weight))
    else:
        return None
    return M, W

def compute_g_value(model):
    layers = []
    W_vals = []
    for layer in model.modules():
        if isinstance(layer, (MaskedLinear)):
            M, W = get_squared_weight_matrix(layer)
            if M is not None:
                layers.append(M)
            if W is not None:
                W_vals.append(W)
    numer = 0.0
    denom = 0.0

    for i in range(len(layers) - 1):
        M1 = layers[i]
        M2 = layers[i+1]

        # M1: [out1, in1]; M2: [out2, in2] → treat shared dim as "middle"
        # So transpose M1 to [in1, out1] and M2 to [in2, out2]
        # sum over matching dimension (out1 == in2)
        M1_sq = M1.pow(2)  # shape: [out1, in1]
        M2_sq = M2.pow(2)  # shape: [out2, in2]
        
        # Align dimension for matching: M1.T: [in1, out1], M2: [out2, in2] ⇒ match on out1 == in2
        if M1.shape[0] != M2.shape[1]:
            # Skip incompatible shapes
            continue

        # Compute: sum_j (sum_i w_{ij}^2) * (sum_k w_{jk}^2)
        # That is, for each shared index j (layer output/input), multiply the sums of incoming and outgoing squared weights
        incoming = M1_sq.sum(dim=1)  # size: [out1] == [shared]
        outgoing = M2_sq.sum(dim=0)  # size: [in2] == [shared]
        numer += (incoming * outgoing).sum().item()

    for i in range(len(layers) - 1):
        M1 = layers[i]
        M2 = layers[i+1]

        W1 = W_vals[i]
        W2 = W_vals[i+1]
        
        # M1: [out1, in1]; M2: [out2, in2] → treat shared dim as "middle"
        # So transpose M1 to [in1, out1] and M2 to [in2, out2]
        # sum over matching dimension (out1 == in2)
        M1_sq = M1.pow(2) / W1
        M2_sq = M2.pow(2) / W2

        # Align dimension for matching: M1.T: [in1, out1], M2: [out2, in2] ⇒ match on out1 == in2
        if M1.shape[0] != M2.shape[1]:
            # Skip incompatible shapes
            continue

        # Compute: sum_j (sum_i w_{ij}^2) * (sum_k w_{jk}^2)
        # That is, for each shared index j (layer output/input), multiply the sums of incoming and outgoing squared weights
        incoming = M1_sq.sum(dim=1)  # size: [out1] == [shared]
        outgoing = M2_sq.sum(dim=0)  # size: [in2] == [shared]
        denom += (incoming * outgoing).sum().item()
        torch.set_printoptions(profile="default")

    return numer/denom

# %%
print("Regarding aggregated w-value")
for label in model_results.keys():
    print(label)
    print(compute_g_value(model_results[label]))
#compute_g_value(model_results["ReLU_NoMask_NoReg"])
# Out:
# Regarding aggregated w-value
# ReLU_NoMask_L1
# 5.082405348097266e-28
# ReLU_Mask_NoReg_t1
# 2.914395990833295e-34
# ReLU_Mask_NoReg_t3
# 1.0538370579484493e-35
# ReLU_Mask_NoReg_t4
# 0.0
# ReLU_Mask_NoReg_t5
# 0.0

# %%
def plot_weight_distributions(model=None, weight_data=None, model_name=None):
    """
    Plot weight and w-value histograms for each layer, either from:
    - a model (with .wval method on layers)
    - OR a dict (state_dict-style) with keys like 'layer.weight' and 'layer.w_values'
    """
    if model is None and weight_data is None:
        raise ValueError("Provide either a model or weight_data")

    weight_layers = []
    wval_layers = []
    layer_names = []

    if weight_data is not None:
        # Group .weight and .w_values by layer name
        grouped = defaultdict(dict)
        for full_name, tensor in weight_data.items():
            *layer_parts, attr = full_name.split('.')
            layer_name = '.'.join(layer_parts)
            grouped[layer_name][attr] = tensor

        for layer_name, tensors in grouped.items():
            if "weight" in tensors and "w_values" in tensors:
                try:
                    W = tensors["weight"].detach().cpu().flatten().numpy()
                    W_val = tensors["w_values"].detach().cpu().flatten().numpy()
                    weight_layers.append(W)
                    wval_layers.append(W_val)
                    layer_names.append(layer_name)
                except Exception as e:
                    print(f"Skipping {layer_name} due to error: {e}")

    elif model is not None:
        # Use the model's layers directly
        for name, layer in model.named_modules():
            if hasattr(layer, "weight") and hasattr(layer, "w_values"):
                try:
                    W = layer.weight.detach().cpu().flatten().numpy()
                    #W_val = layer.wval(layer.weight).detach().cpu().flatten().numpy()
                    W_val = layer.w_values.detach().cpu().flatten().numpy()
                    weight_layers.append(W)
                    wval_layers.append(W_val)
                    layer_names.append(name)
                except Exception as e:
                    print(f"Skipping layer {name} due to error: {e}")

    num_layers = len(weight_layers)
    if num_layers == 0:
        print("No valid layers found with both weights and w-values.")
        return

    plt.figure(figsize=(12, 4 * num_layers))

    # Plot weights
    for i, (weights, name) in enumerate(zip(weight_layers, layer_names)):
        plt.subplot(num_layers, 2, 2 * i + 1)
        sns.histplot(weights, binwidth=0.01, kde=False, color='steelblue')
        plt.title(f"Weight Distribution - {name}")
        plt.xlabel("Weight Value")
        plt.ylabel("Frequency")
        plt.xlim([-1, 1])

    # Plot w-values
    for i, (wvals, name) in enumerate(zip(wval_layers, layer_names)):
        plt.subplot(num_layers, 2, 2 * i + 2)
        sns.histplot(wvals, binwidth=0.1, kde=False, color='darkorange')
        plt.title(f"W-Value Distribution - {name}")
        plt.xlabel("W-Value")
        plt.ylabel("Frequency")
        plt.xlim([0, 4])

    plt.tight_layout()
    #os.makedirs(plot_dir+"-"+model_name, exist_ok=True)
    plt.savefig(f"{plot_dir}-{model_name}-W_WVs.png")
    plt.show()

# %%
model = "ReLU_Mask_NoReg_t4"
plot_weight_distributions(model=model_results[model], model_name=model)

# %%
model = "ReLU_NoMask_L1"
plot_weight_distributions(model=model_results[model], model_name=model)

# %%
model = "ReLU_Mask_NoReg_t3"
plot_weight_distributions(model=model_results[model], model_name=model)

# %%
model = "ReLU_Mask_NoReg_t5"
plot_weight_distributions(model=model_results[model], model_name=model)

# %%
model = "ReLU_Mask_NoReg_t1"
plot_weight_distributions(model=model_results[model], model_name=model)

# %%
#m_75 = torch.load('runs/20250710_141920_act-ReLU_mask-True_thresh-0.69_reg-None_epochs-5-20Newsgroups/model.pth')
