# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader, Subset, random_split
import torch.nn.utils.weight_norm as weight_norm
import torch.nn.functional as F
import numpy as np
import scipy as sp
from scipy.stats import norm, shapiro, binom
from scipy.special import beta

import matplotlib.pyplot as plt
import random
import time as t
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_covtype, fetch_openml, fetch_20newsgroups
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
import os
import urllib
import gzip
import zipfile
import json
from datetime import datetime

from sklearn.feature_extraction.text import TfidfVectorizer
import datasets
from datasets import load_dataset
import seaborn as sns
import ipynbname
from collections import defaultdict

notebook_name = ipynbname.name()
# from torchtime.data import PhysioNet2012
# from torchtime.collate import packed_sequence

# %%
# ✅ 1. Config

device_id = 4
device = "cuda:"+str(device_id) if torch.cuda.is_available() else 'cpu'

BATCH_SIZE = 128
DATA_PATH = './data'
SEED = 42
torch.manual_seed(SEED)

# ✅ Load text data
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))
X_raw = newsgroups.data
y = newsgroups.target  # Labels are 0 to 19

# ✅ Vectorize using TF-IDF
vectorizer = TfidfVectorizer(max_features=2000, stop_words='english')
X_vec = vectorizer.fit_transform(X_raw).toarray()

# ✅ Split train/test
X_train, X_test, y_train, y_test = train_test_split(
    X_vec, y, test_size=0.2, random_state=42, stratify=y
)

# ✅ Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# ✅ Wrap in DataLoaders
BATCH_SIZE = 128
train_data = TensorDataset(X_train_tensor, y_train_tensor)
test_data = TensorDataset(X_test_tensor, y_test_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
class MLP(nn.Module):
    # For UCI Income: input_dim=X_train_tensor.shape[1], hidden_dims=[64, 32], output_dim=2,
    # For CoverType input_dim=54, hidden_dims=[256, 128, 64], output_dim=7,
    # CIFAR-10 its input_dim=3072, hidden_dims=[2048, 1024, 1024, 512, 256, 128], output_dim=10,
    # CIFAR-100 its input_dim=3072, hidden_dims=[2048, 1024, 1024, 512], output_dim=100,
    # For FashionMNIST its input_dim=784, hidden_dims=[512, 256, 128], output_dim=10, dropout=0.2,
    # For Yelp dataset input_dim=10000, hidden_dims=[512], output_dim=2, 
    # For 20Newsgroups input_dim=2000, hidden_dims=[512, 256, 128], num_classes=20
    def __init__(self, input_dim=2000, hidden_dims=[512, 256, 128], output_dim=20, dropout=0.3, activation_fn=nn.ReLU, use_mask=True, threshold=1):
        super(MLP, self).__init__()
        self.activation = activation_fn()
        self.use_mask = use_mask
        layers = []
        dims = [input_dim] + hidden_dims
        self.table = {}
        x_vals = np.linspace(0,1,100000)
        for b in dims:
            self.table[b] = sp.special.betainc(1/2, 0.5*(b - 1), x_vals)

        for i in range(len(dims) - 1):
            layers += [
                MaskedLinear(dims[i], dims[i+1], use_mask=self.use_mask, threshold=threshold, table=self.table),
                # nn.BatchNorm1d(dims[i+1]),
                self.activation,
                # nn.Dropout(dropout)
            ]
    
        layers.append(MaskedLinear(dims[-1], output_dim, use_mask=self.use_mask, threshold=threshold, table=self.table))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

class MaskedLinear(nn.Linear):
    def __init__(self, in_features, out_features, bias=True, threshold=1, use_mask=True, table={}):
        super().__init__(in_features, out_features, bias)
        self.threshold = torch.tensor(threshold) #-torch.log10()
        self.use_mask = use_mask
        self.register_buffer("entropy", torch.tensor(0.0))
        self.table = table
        self.register_buffer("w_values", torch.zeros_like(self.weight))
        
    def wval(self, M):
        a = t.time()
        L = M.shape[1] if M.ndim == 2 else M.shape[1] * M.shape[2] * M.shape[3]

        alpha = torch.as_tensor(1/2, dtype=M.dtype, device=M.device)
        beta = torch.as_tensor((L-1)/2, dtype=M.dtype, device=M.device)
    
        # Normalize each weight vector going from a node in A to layer B
        M_normed = F.normalize(M, p=2, dim=1)
        
        M_clamped = torch.clamp(M_normed**2, min=1e-8, max=1-1e-8)

        M_cpu = M_clamped.detach().cpu().numpy()
        alpha_cpu = float(alpha.item())  # scalar
        beta_cpu = float(beta.item())    # scalar
        
        index_matrix = np.round(100000 * M_cpu).astype(int)
        
        # Optional: clamp to [0, 100] just in case of rounding errors
        index_matrix = np.clip(index_matrix, 0, 100000)
        
        # Step 2: Use advanced NumPy indexing
        table_vals = np.array(self.table[L])  # Make sure this is a NumPy array
        cdf_np = table_vals[index_matrix]     # Fast lookup for entire matrix
        
        cdf = torch.tensor(cdf_np, dtype=M_clamped.dtype, device=M_clamped.device)

        beta_surv = torch.clamp(1 - cdf, min=1e-8, max=1-1e-8)  # Survival function
        
        w_val = -torch.log(beta_surv)

        assert w_val.shape == M.shape

        return w_val

    def forward(self, input):
        if self.use_mask:
            # Compute significance
            self.w_values = self.wval(self.weight)
    
            # Create binary mask
            mask = (self.w_values >= self.threshold).float()
    
            # Apply the mask (zero out insignificant weights)
            masked_weight = self.weight * mask
        else:
            masked_weight = self.weight
            self.w_values = self.wval(self.weight)

        flat_M = torch.flatten(masked_weight)
        flat_M_2 = flat_M.pow(2)

        entropy_value = sp.stats.entropy(flat_M_2.detach().cpu().numpy())
        ent_tensor = torch.tensor(entropy_value)
        self.entropy.copy_(ent_tensor)
        return F.linear(input, masked_weight, self.bias)

# %%
def save_run_data_txt(
    base_dir, model, config, train_losses, train_accuracies,
    test_losses, test_accuracies
):
    # Create a unique folder name
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    folder_name = (
        f"{timestamp}_act-{config['activation']}_mask-{config['use_mask']}"
        f"_thresh-{round(config['threshold'],2)}_reg-{config['regularization']}_epochs-{config['epochs']}-{notebook_name}"
    )
    path = os.path.join(base_dir, folder_name)
    os.makedirs(path, exist_ok=True)

    # Save model weights
    torch.save(model.state_dict(), os.path.join(path, "model.pth"))

    # Save run configuration
    with open(os.path.join(path, "config.json"), "w") as f:
        json.dump(config, f, indent=4)

    # Helper function to write a list of floats to a .txt file
    def write_list(filename, values):
        with open(os.path.join(path, filename), "w") as f:
            for v in values:
                f.write(f"{v:.6f}\n")

    # Save all metrics
    write_list("train_losses.txt", train_losses)
    write_list("train_accuracies.txt", train_accuracies)
    write_list("test_losses.txt", test_losses)
    write_list("test_accuracies.txt", test_accuracies)

    print(f"Run data saved to {path}")

    return folder_name

# %%
def train_and_collect_metrics(
    train_loader,
    test_loader,
    act,
    use_mask,
    regularization=None,
    lambda_reg=0.0,
    initial_weights=None,
    epochs=5,
    the_device='cpu',
    threshold=1,
):
    model = MLP(activation_fn=act, use_mask=use_mask, threshold=threshold).to(the_device)
        
    if initial_weights is not None:
        model.load_state_dict({k: v.clone().to(the_device) for k, v in initial_weights.items()})

    model = model.to(the_device)
    model = nn.DataParallel(model, device_ids=[device_id])

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-4)

    train_losses = []
    train_accuracies = []
    test_losses = []
    test_accuracies = []

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(the_device), labels.to(the_device)
            optimizer.zero_grad()
            output = model(images)
            loss = criterion(output, labels)

            if regularization == "L1" and lambda_reg > 0:
                reg_term = sum(p.abs().sum() for p in model.parameters())
                loss += lambda_reg * reg_term
            elif regularization == "L2" and lambda_reg > 0:
                reg_term = sum((p ** 2).sum() for p in model.parameters())
                loss += lambda_reg * reg_term

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            predicted = output.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        avg_loss = epoch_loss / len(train_loader)
        accuracy = 100 * correct / total
        train_losses.append(avg_loss)
        train_accuracies.append(accuracy)
        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {avg_loss:.4f}, Train Accuracy: {accuracy:.2f}%")

        # Compute test loss every 10 epochs
        if (epoch + 1) % 5 == 0 or epoch == epochs - 1:
            model.eval()
            test_loss = 0.0
            correct = 0
            total = 0
            with torch.no_grad():
                for images, labels in test_loader:
                    images, labels = images.to(the_device), labels.to(the_device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    test_loss += loss.item()
                    predicted = outputs.argmax(dim=1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
            avg_test_loss = test_loss / len(test_loader)
            test_acc = 100 * correct / total
            test_losses.append(avg_test_loss)
            test_accuracies.append(test_acc)
            print(f"[Epoch {epoch+1}] Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_acc:.2f}%")

    # Final test evaluation
    model.eval()
    correct = 0
    total = 0
    total_loss = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(the_device), labels.to(the_device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            predicted = outputs.argmax(dim=1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = total_loss / len(test_loader)
    test_accuracy = 100 * correct / total
    print(f"[use_mask={use_mask}, reg={regularization}] Final Test Accuracy: {test_accuracy:.2f}%, Test Loss: {test_loss:.4f}")
    
    
    config = {
    "activation": act.__name__ if hasattr(act, "__name__") else str(act),
    "use_mask": use_mask,
    "threshold": threshold,
    "regularization": regularization,
    "lambda_reg": lambda_reg,
    "epochs": epochs,
    "device": the_device,
    }

    folder_name = save_run_data_txt(
        base_dir="runs_"+notebook_name,
        model=model,
        config=config,
        train_losses=train_losses,
        train_accuracies=train_accuracies,
        test_losses=test_losses,
        test_accuracies=test_accuracies,
    )
    
    return model.module, test_losses, test_accuracies, train_losses, train_accuracies, folder_name

# %%
torch.manual_seed(42)
EPOCHS = 100
#THRESHOLD = 0.4

baseline_model = MLP(activation_fn = nn.ReLU, use_mask=False, threshold=0.7).cpu()
# Save baseline weights
initial_weights = {k: v.clone().detach().cpu() for k, v in baseline_model.state_dict().items()}

# Run all configurations
model_results = {}
test_losses = {}
times = {}
test_accs = {}
train_losses = {}
train_accs = {}
folder_names = []

configs = [
    # ("ReLU_NoMask_NoReg", nn.ReLU, False, None, 0.0, 0.7),
    ("ReLU_NoMask_L1", nn.ReLU, False, "L1", 1e-6, 0.7),
    # ("ReLU_NoMask_L2", nn.ReLU, False, "L2", 1e-6, 0.7),
    ("ReLU_Mask_NoReg_t1", nn.ReLU, True, None, 0.0, -np.log(0.90)),
    # ("ReLU_Mask_NoReg_t2", nn.ReLU, True, None, 0.0, -np.log(0.75)),
    ("ReLU_Mask_NoReg_t3", nn.ReLU, True, None, 0.0, -np.log(0.50)),
    ("ReLU_Mask_NoReg_t4", nn.ReLU, True, None, 0.0, -np.log(0.25)),
    ("ReLU_Mask_NoReg_t5", nn.ReLU, True, None, 0.0, -np.log(0.10)),
    # ("Sigmoid_NoMask_NoReg", nn.Sigmoid, False, None, 0.0, 0.7),
    # ("Sigmoid_NoMask_L1", nn.Sigmoid, False, "L1", 1e-6, 0.7),
    # ("Sigmoid_Mask_NoReg", nn.Sigmoid, True, None, 0.0, 0.7),
]

start = t.time()

for label, act, use_mask, reg_type, lambd, thresh in configs:
    iter_i = t.time()
    model, test_loss, test_acc, train_loss, train_acc, folder_name = train_and_collect_metrics(train_loader, test_loader, act, use_mask, reg_type, lambd, initial_weights, epochs=EPOCHS, the_device=device, threshold=thresh)
    test_losses[label] = test_loss
    model_results[label] = model
    test_accs[label] = test_acc
    train_losses[label] = train_loss
    train_accs[label] = train_acc

    folder_names.append(folder_name)
    iter_f = t.time()
    delta = iter_f - iter_i
    print(delta)
    times[label] = delta
    
total = t.time() - start
print(total/60)
# Out:
# Epoch 1/100 - Train Loss: 3.0073, Train Accuracy: 5.25%
# Epoch 2/100 - Train Loss: 2.8895, Train Accuracy: 17.29%
# Epoch 3/100 - Train Loss: 2.3431, Train Accuracy: 29.42%
# Epoch 4/100 - Train Loss: 1.9340, Train Accuracy: 39.65%
# Epoch 5/100 - Train Loss: 1.7216, Train Accuracy: 44.99%
# [Epoch 5] Test Loss: 1.7326, Test Accuracy: 42.65%
# Epoch 6/100 - Train Loss: 1.5955, Train Accuracy: 48.89%
# Epoch 7/100 - Train Loss: 1.5073, Train Accuracy: 52.18%
# Epoch 8/100 - Train Loss: 1.4328, Train Accuracy: 54.73%
# Epoch 9/100 - Train Loss: 1.3669, Train Accuracy: 57.56%
# Epoch 10/100 - Train Loss: 1.3087, Train Accuracy: 59.62%
# [Epoch 10] Test Loss: 1.5190, Test Accuracy: 52.81%
# Epoch 11/100 - Train Loss: 1.2580, Train Accuracy: 61.08%
# Epoch 12/100 - Train Loss: 1.2183, Train Accuracy: 62.11%
# Epoch 13/100 - Train Loss: 1.1852, Train Accuracy: 63.08%
# Epoch 14/100 - Train Loss: 1.1575, Train Accuracy: 63.68%
# Epoch 15/100 - Train Loss: 1.1329, Train Accuracy: 64.25%
# [Epoch 15] Test Loss: 1.4707, Test Accuracy: 55.57%
# Epoch 16/100 - Train Loss: 1.1105, Train Accuracy: 65.12%
# Epoch 17/100 - Train Loss: 1.0918, Train Accuracy: 65.73%
# Epoch 18/100 - Train Loss: 1.0729, Train Accuracy: 66.25%
# Epoch 19/100 - Train Loss: 1.0573, Train Accuracy: 67.05%
# Epoch 20/100 - Train Loss: 1.0404, Train Accuracy: 67.20%
# [Epoch 20] Test Loss: 1.4868, Test Accuracy: 56.39%
# Epoch 21/100 - Train Loss: 1.0264, Train Accuracy: 67.79%
# Epoch 22/100 - Train Loss: 1.0125, Train Accuracy: 68.07%
# Epoch 23/100 - Train Loss: 0.9980, Train Accuracy: 68.63%
# Epoch 24/100 - Train Loss: 0.9864, Train Accuracy: 68.94%
# Epoch 25/100 - Train Loss: 0.9744, Train Accuracy: 69.59%
# [Epoch 25] Test Loss: 1.5139, Test Accuracy: 56.87%
# Epoch 26/100 - Train Loss: 0.9637, Train Accuracy: 69.92%
# Epoch 27/100 - Train Loss: 0.9510, Train Accuracy: 70.29%
# Epoch 28/100 - Train Loss: 0.9409, Train Accuracy: 70.49%
# Epoch 29/100 - Train Loss: 0.9318, Train Accuracy: 70.88%
# Epoch 30/100 - Train Loss: 0.9208, Train Accuracy: 71.18%
# [Epoch 30] Test Loss: 1.5409, Test Accuracy: 56.92%
# Epoch 31/100 - Train Loss: 0.9112, Train Accuracy: 71.51%
# Epoch 32/100 - Train Loss: 0.9012, Train Accuracy: 71.96%
# Epoch 33/100 - Train Loss: 0.8921, Train Accuracy: 72.23%
# Epoch 34/100 - Train Loss: 0.8829, Train Accuracy: 72.27%
# Epoch 35/100 - Train Loss: 0.8757, Train Accuracy: 72.67%
# [Epoch 35] Test Loss: 1.5857, Test Accuracy: 57.14%
# Epoch 36/100 - Train Loss: 0.8654, Train Accuracy: 73.14%
# Epoch 37/100 - Train Loss: 0.8569, Train Accuracy: 73.66%
# Epoch 38/100 - Train Loss: 0.8495, Train Accuracy: 73.81%
# Epoch 39/100 - Train Loss: 0.8402, Train Accuracy: 74.10%
# Epoch 40/100 - Train Loss: 0.8326, Train Accuracy: 74.55%
# [Epoch 40] Test Loss: 1.6320, Test Accuracy: 57.11%
# Epoch 41/100 - Train Loss: 0.8239, Train Accuracy: 74.69%
# Epoch 42/100 - Train Loss: 0.8151, Train Accuracy: 74.87%
# Epoch 43/100 - Train Loss: 0.8068, Train Accuracy: 75.24%
# Epoch 44/100 - Train Loss: 0.7979, Train Accuracy: 75.50%
# Epoch 45/100 - Train Loss: 0.7902, Train Accuracy: 75.56%
# [Epoch 45] Test Loss: 1.6867, Test Accuracy: 57.29%
# Epoch 46/100 - Train Loss: 0.7812, Train Accuracy: 76.09%
# Epoch 47/100 - Train Loss: 0.7739, Train Accuracy: 76.21%
# Epoch 48/100 - Train Loss: 0.7661, Train Accuracy: 76.57%
# Epoch 49/100 - Train Loss: 0.7567, Train Accuracy: 76.99%
# Epoch 50/100 - Train Loss: 0.7486, Train Accuracy: 77.15%
# [Epoch 50] Test Loss: 1.7453, Test Accuracy: 57.37%
# Epoch 51/100 - Train Loss: 0.7405, Train Accuracy: 77.65%
# Epoch 52/100 - Train Loss: 0.7326, Train Accuracy: 77.66%
# Epoch 53/100 - Train Loss: 0.7234, Train Accuracy: 78.22%
# Epoch 54/100 - Train Loss: 0.7161, Train Accuracy: 78.44%
# Epoch 55/100 - Train Loss: 0.7084, Train Accuracy: 78.65%
# [Epoch 55] Test Loss: 1.8107, Test Accuracy: 57.21%
# Epoch 56/100 - Train Loss: 0.6994, Train Accuracy: 78.93%
# Epoch 57/100 - Train Loss: 0.6901, Train Accuracy: 79.44%
# Epoch 58/100 - Train Loss: 0.6811, Train Accuracy: 79.64%
# Epoch 59/100 - Train Loss: 0.6752, Train Accuracy: 79.90%
# Epoch 60/100 - Train Loss: 0.6650, Train Accuracy: 80.35%
# [Epoch 60] Test Loss: 1.8807, Test Accuracy: 56.58%
# Epoch 61/100 - Train Loss: 0.6570, Train Accuracy: 80.58%
# Epoch 62/100 - Train Loss: 0.6506, Train Accuracy: 80.95%
# Epoch 63/100 - Train Loss: 0.6403, Train Accuracy: 81.26%
# Epoch 64/100 - Train Loss: 0.6311, Train Accuracy: 81.59%
# Epoch 65/100 - Train Loss: 0.6213, Train Accuracy: 82.05%
# [Epoch 65] Test Loss: 1.9609, Test Accuracy: 56.55%
# Epoch 66/100 - Train Loss: 0.6142, Train Accuracy: 82.35%
# Epoch 67/100 - Train Loss: 0.6035, Train Accuracy: 82.77%
# Epoch 68/100 - Train Loss: 0.5952, Train Accuracy: 82.90%
# Epoch 69/100 - Train Loss: 0.5853, Train Accuracy: 83.50%
# Epoch 70/100 - Train Loss: 0.5759, Train Accuracy: 83.76%
# [Epoch 70] Test Loss: 2.0575, Test Accuracy: 56.55%
# Epoch 71/100 - Train Loss: 0.5675, Train Accuracy: 84.11%
# Epoch 72/100 - Train Loss: 0.5575, Train Accuracy: 84.51%
# Epoch 73/100 - Train Loss: 0.5471, Train Accuracy: 84.88%
# Epoch 74/100 - Train Loss: 0.5380, Train Accuracy: 85.34%
# Epoch 75/100 - Train Loss: 0.5283, Train Accuracy: 85.75%
# [Epoch 75] Test Loss: 2.1574, Test Accuracy: 56.15%
# Epoch 76/100 - Train Loss: 0.5191, Train Accuracy: 86.17%
# Epoch 77/100 - Train Loss: 0.5080, Train Accuracy: 86.46%
# Epoch 78/100 - Train Loss: 0.4994, Train Accuracy: 86.81%
# Epoch 79/100 - Train Loss: 0.4894, Train Accuracy: 87.34%
# Epoch 80/100 - Train Loss: 0.4781, Train Accuracy: 87.65%
# [Epoch 80] Test Loss: 2.2748, Test Accuracy: 56.10%
# Epoch 81/100 - Train Loss: 0.4684, Train Accuracy: 87.98%
# Epoch 82/100 - Train Loss: 0.4585, Train Accuracy: 88.47%
# Epoch 83/100 - Train Loss: 0.4493, Train Accuracy: 88.92%
# Epoch 84/100 - Train Loss: 0.4383, Train Accuracy: 89.15%
# Epoch 85/100 - Train Loss: 0.4280, Train Accuracy: 89.55%
# [Epoch 85] Test Loss: 2.4097, Test Accuracy: 55.97%
# Epoch 86/100 - Train Loss: 0.4177, Train Accuracy: 90.08%
# Epoch 87/100 - Train Loss: 0.4084, Train Accuracy: 90.43%
# Epoch 88/100 - Train Loss: 0.3967, Train Accuracy: 90.90%
# Epoch 89/100 - Train Loss: 0.3864, Train Accuracy: 91.24%
# Epoch 90/100 - Train Loss: 0.3762, Train Accuracy: 91.52%
# [Epoch 90] Test Loss: 2.5462, Test Accuracy: 55.78%
# Epoch 91/100 - Train Loss: 0.3662, Train Accuracy: 91.99%
# Epoch 92/100 - Train Loss: 0.3563, Train Accuracy: 92.19%
# Epoch 93/100 - Train Loss: 0.3471, Train Accuracy: 92.66%
# Epoch 94/100 - Train Loss: 0.3376, Train Accuracy: 92.80%
# Epoch 95/100 - Train Loss: 0.3273, Train Accuracy: 93.19%
# [Epoch 95] Test Loss: 2.6944, Test Accuracy: 55.92%
# Epoch 96/100 - Train Loss: 0.3182, Train Accuracy: 93.52%
# Epoch 97/100 - Train Loss: 0.3090, Train Accuracy: 93.77%
# Epoch 98/100 - Train Loss: 0.3005, Train Accuracy: 94.10%
# Epoch 99/100 - Train Loss: 0.2917, Train Accuracy: 94.38%
# Epoch 100/100 - Train Loss: 0.2831, Train Accuracy: 94.65%
# [Epoch 100] Test Loss: 2.8720, Test Accuracy: 55.86%
# [use_mask=False, reg=L1] Final Test Accuracy: 55.86%, Test Loss: 2.8720
# Run data saved to runs_20Newsgroups/20250711_140830_act-ReLU_mask-False_thresh-0.7_reg-L1_epochs-100-20Newsgroups
# 627.940934419632
# Epoch 1/100 - Train Loss: 2.9944, Train Accuracy: 5.27%
# Epoch 2/100 - Train Loss: 2.9172, Train Accuracy: 17.31%
# Epoch 3/100 - Train Loss: 2.5002, Train Accuracy: 26.16%
# Epoch 4/100 - Train Loss: 2.1351, Train Accuracy: 36.85%
# Epoch 5/100 - Train Loss: 1.9047, Train Accuracy: 41.43%
# [Epoch 5] Test Loss: 1.8835, Test Accuracy: 39.97%
# Epoch 6/100 - Train Loss: 1.7604, Train Accuracy: 44.53%
# Epoch 7/100 - Train Loss: 1.6572, Train Accuracy: 47.77%
# Epoch 8/100 - Train Loss: 1.5781, Train Accuracy: 50.10%
# Epoch 9/100 - Train Loss: 1.5099, Train Accuracy: 52.69%
# Epoch 10/100 - Train Loss: 1.4536, Train Accuracy: 54.17%
# [Epoch 10] Test Loss: 1.5932, Test Accuracy: 48.83%
# Epoch 11/100 - Train Loss: 1.4044, Train Accuracy: 55.94%
# Epoch 12/100 - Train Loss: 1.3605, Train Accuracy: 57.23%
# Epoch 13/100 - Train Loss: 1.3221, Train Accuracy: 58.85%
# Epoch 14/100 - Train Loss: 1.2864, Train Accuracy: 59.70%
# Epoch 15/100 - Train Loss: 1.2543, Train Accuracy: 60.85%
# [Epoch 15] Test Loss: 1.4899, Test Accuracy: 54.03%
# Epoch 16/100 - Train Loss: 1.2253, Train Accuracy: 61.65%
# Epoch 17/100 - Train Loss: 1.1987, Train Accuracy: 62.58%
# Epoch 18/100 - Train Loss: 1.1732, Train Accuracy: 63.25%
# Epoch 19/100 - Train Loss: 1.1515, Train Accuracy: 63.84%
# Epoch 20/100 - Train Loss: 1.1286, Train Accuracy: 64.55%
# [Epoch 20] Test Loss: 1.4311, Test Accuracy: 56.23%
# Epoch 21/100 - Train Loss: 1.1086, Train Accuracy: 65.04%
# Epoch 22/100 - Train Loss: 1.0902, Train Accuracy: 65.70%
# Epoch 23/100 - Train Loss: 1.0733, Train Accuracy: 66.22%
# Epoch 24/100 - Train Loss: 1.0562, Train Accuracy: 66.64%
# Epoch 25/100 - Train Loss: 1.0412, Train Accuracy: 66.89%
# [Epoch 25] Test Loss: 1.4076, Test Accuracy: 56.98%
# Epoch 26/100 - Train Loss: 1.0275, Train Accuracy: 67.37%
# Epoch 27/100 - Train Loss: 1.0140, Train Accuracy: 67.82%
# Epoch 28/100 - Train Loss: 1.0020, Train Accuracy: 68.28%
# Epoch 29/100 - Train Loss: 0.9885, Train Accuracy: 68.46%
# Epoch 30/100 - Train Loss: 0.9785, Train Accuracy: 68.73%
# [Epoch 30] Test Loss: 1.4002, Test Accuracy: 57.85%
# Epoch 31/100 - Train Loss: 0.9659, Train Accuracy: 69.32%
# Epoch 32/100 - Train Loss: 0.9567, Train Accuracy: 69.40%
# Epoch 33/100 - Train Loss: 0.9465, Train Accuracy: 69.81%
# Epoch 34/100 - Train Loss: 0.9364, Train Accuracy: 70.10%
# Epoch 35/100 - Train Loss: 0.9259, Train Accuracy: 70.53%
# [Epoch 35] Test Loss: 1.4088, Test Accuracy: 57.93%
# Epoch 36/100 - Train Loss: 0.9175, Train Accuracy: 70.76%
# Epoch 37/100 - Train Loss: 0.9088, Train Accuracy: 71.01%
# Epoch 38/100 - Train Loss: 0.9014, Train Accuracy: 71.22%
# Epoch 39/100 - Train Loss: 0.8917, Train Accuracy: 71.82%
# Epoch 40/100 - Train Loss: 0.8842, Train Accuracy: 71.92%
# [Epoch 40] Test Loss: 1.4241, Test Accuracy: 58.25%
# Epoch 41/100 - Train Loss: 0.8771, Train Accuracy: 71.80%
# Epoch 42/100 - Train Loss: 0.8696, Train Accuracy: 72.27%
# Epoch 43/100 - Train Loss: 0.8617, Train Accuracy: 72.47%
# Epoch 44/100 - Train Loss: 0.8535, Train Accuracy: 72.54%
# Epoch 45/100 - Train Loss: 0.8483, Train Accuracy: 72.91%
# [Epoch 45] Test Loss: 1.4449, Test Accuracy: 58.83%
# Epoch 46/100 - Train Loss: 0.8413, Train Accuracy: 73.15%
# Epoch 47/100 - Train Loss: 0.8351, Train Accuracy: 73.64%
# Epoch 48/100 - Train Loss: 0.8287, Train Accuracy: 73.59%
# Epoch 49/100 - Train Loss: 0.8216, Train Accuracy: 73.80%
# Epoch 50/100 - Train Loss: 0.8159, Train Accuracy: 74.02%
# [Epoch 50] Test Loss: 1.4704, Test Accuracy: 58.59%
# Epoch 51/100 - Train Loss: 0.8093, Train Accuracy: 74.24%
# Epoch 52/100 - Train Loss: 0.8030, Train Accuracy: 74.35%
# Epoch 53/100 - Train Loss: 0.7980, Train Accuracy: 74.56%
# Epoch 54/100 - Train Loss: 0.7932, Train Accuracy: 74.80%
# Epoch 55/100 - Train Loss: 0.7867, Train Accuracy: 74.99%
# [Epoch 55] Test Loss: 1.4980, Test Accuracy: 58.70%
# Epoch 56/100 - Train Loss: 0.7818, Train Accuracy: 75.21%
# Epoch 57/100 - Train Loss: 0.7760, Train Accuracy: 75.42%
# Epoch 58/100 - Train Loss: 0.7712, Train Accuracy: 75.53%
# Epoch 59/100 - Train Loss: 0.7673, Train Accuracy: 75.92%
# Epoch 60/100 - Train Loss: 0.7608, Train Accuracy: 75.84%
# [Epoch 60] Test Loss: 1.5289, Test Accuracy: 58.65%
# Epoch 61/100 - Train Loss: 0.7558, Train Accuracy: 76.04%
# Epoch 62/100 - Train Loss: 0.7499, Train Accuracy: 76.27%
# Epoch 63/100 - Train Loss: 0.7458, Train Accuracy: 76.36%
# Epoch 64/100 - Train Loss: 0.7395, Train Accuracy: 76.66%
# Epoch 65/100 - Train Loss: 0.7357, Train Accuracy: 76.64%
# [Epoch 65] Test Loss: 1.5599, Test Accuracy: 58.75%
# Epoch 66/100 - Train Loss: 0.7312, Train Accuracy: 76.86%
# Epoch 67/100 - Train Loss: 0.7257, Train Accuracy: 77.10%
# Epoch 68/100 - Train Loss: 0.7215, Train Accuracy: 77.30%
# Epoch 69/100 - Train Loss: 0.7171, Train Accuracy: 77.44%
# Epoch 70/100 - Train Loss: 0.7127, Train Accuracy: 77.59%
# [Epoch 70] Test Loss: 1.5918, Test Accuracy: 59.10%
# Epoch 71/100 - Train Loss: 0.7073, Train Accuracy: 77.67%
# Epoch 72/100 - Train Loss: 0.7040, Train Accuracy: 77.84%
# Epoch 73/100 - Train Loss: 0.6983, Train Accuracy: 78.11%
# Epoch 74/100 - Train Loss: 0.6935, Train Accuracy: 78.35%
# Epoch 75/100 - Train Loss: 0.6898, Train Accuracy: 78.29%
# [Epoch 75] Test Loss: 1.6266, Test Accuracy: 58.89%
# Epoch 76/100 - Train Loss: 0.6851, Train Accuracy: 78.68%
# Epoch 77/100 - Train Loss: 0.6802, Train Accuracy: 78.68%
# Epoch 78/100 - Train Loss: 0.6751, Train Accuracy: 78.91%
# Epoch 79/100 - Train Loss: 0.6712, Train Accuracy: 79.11%
# Epoch 80/100 - Train Loss: 0.6669, Train Accuracy: 79.11%
# [Epoch 80] Test Loss: 1.6628, Test Accuracy: 58.91%
# Epoch 81/100 - Train Loss: 0.6617, Train Accuracy: 79.38%
# Epoch 82/100 - Train Loss: 0.6578, Train Accuracy: 79.56%
# Epoch 83/100 - Train Loss: 0.6534, Train Accuracy: 79.47%
# Epoch 84/100 - Train Loss: 0.6493, Train Accuracy: 79.67%
# Epoch 85/100 - Train Loss: 0.6443, Train Accuracy: 80.05%
# [Epoch 85] Test Loss: 1.6998, Test Accuracy: 58.91%
# Epoch 86/100 - Train Loss: 0.6402, Train Accuracy: 80.13%
# Epoch 87/100 - Train Loss: 0.6350, Train Accuracy: 80.39%
# Epoch 88/100 - Train Loss: 0.6310, Train Accuracy: 80.39%
# Epoch 89/100 - Train Loss: 0.6259, Train Accuracy: 80.55%
# Epoch 90/100 - Train Loss: 0.6218, Train Accuracy: 80.68%
# [Epoch 90] Test Loss: 1.7368, Test Accuracy: 58.59%
# Epoch 91/100 - Train Loss: 0.6173, Train Accuracy: 81.04%
# Epoch 92/100 - Train Loss: 0.6133, Train Accuracy: 80.99%
# Epoch 93/100 - Train Loss: 0.6086, Train Accuracy: 81.19%
# Epoch 94/100 - Train Loss: 0.6031, Train Accuracy: 81.51%
# Epoch 95/100 - Train Loss: 0.5998, Train Accuracy: 81.41%
# [Epoch 95] Test Loss: 1.7781, Test Accuracy: 58.73%
# Epoch 96/100 - Train Loss: 0.5943, Train Accuracy: 81.80%
# Epoch 97/100 - Train Loss: 0.5908, Train Accuracy: 81.92%
# Epoch 98/100 - Train Loss: 0.5855, Train Accuracy: 82.10%
# Epoch 99/100 - Train Loss: 0.5817, Train Accuracy: 82.37%
# Epoch 100/100 - Train Loss: 0.5776, Train Accuracy: 82.44%
# [Epoch 100] Test Loss: 1.8142, Test Accuracy: 58.59%
# [use_mask=True, reg=None] Final Test Accuracy: 58.59%, Test Loss: 1.8142
# Run data saved to runs_20Newsgroups/20250711_142116_act-ReLU_mask-True_thresh-0.11_reg-None_epochs-100-20Newsgroups
# 765.6806654930115
# Epoch 1/100 - Train Loss: 2.9960, Train Accuracy: 5.23%
# Epoch 2/100 - Train Loss: 2.9660, Train Accuracy: 12.16%
# Epoch 3/100 - Train Loss: 2.7451, Train Accuracy: 20.00%
# Epoch 4/100 - Train Loss: 2.4461, Train Accuracy: 26.44%
# Epoch 5/100 - Train Loss: 2.2442, Train Accuracy: 33.11%
# [Epoch 5] Test Loss: 2.1903, Test Accuracy: 32.79%
# Epoch 6/100 - Train Loss: 2.0839, Train Accuracy: 37.00%
# Epoch 7/100 - Train Loss: 1.9580, Train Accuracy: 39.96%
# Epoch 8/100 - Train Loss: 1.8618, Train Accuracy: 42.99%
# Epoch 9/100 - Train Loss: 1.7846, Train Accuracy: 45.03%
# Epoch 10/100 - Train Loss: 1.7208, Train Accuracy: 47.22%
# [Epoch 10] Test Loss: 1.7898, Test Accuracy: 43.45%
# Epoch 11/100 - Train Loss: 1.6657, Train Accuracy: 48.43%
# Epoch 12/100 - Train Loss: 1.6172, Train Accuracy: 49.95%
# Epoch 13/100 - Train Loss: 1.5720, Train Accuracy: 51.20%
# Epoch 14/100 - Train Loss: 1.5334, Train Accuracy: 52.59%
# Epoch 15/100 - Train Loss: 1.4972, Train Accuracy: 53.69%
# [Epoch 15] Test Loss: 1.6372, Test Accuracy: 48.91%
# Epoch 16/100 - Train Loss: 1.4633, Train Accuracy: 54.66%
# Epoch 17/100 - Train Loss: 1.4320, Train Accuracy: 55.67%
# Epoch 18/100 - Train Loss: 1.4033, Train Accuracy: 56.94%
# Epoch 19/100 - Train Loss: 1.3764, Train Accuracy: 57.59%
# Epoch 20/100 - Train Loss: 1.3512, Train Accuracy: 58.41%
# [Epoch 20] Test Loss: 1.5490, Test Accuracy: 52.41%
# Epoch 21/100 - Train Loss: 1.3282, Train Accuracy: 59.04%
# Epoch 22/100 - Train Loss: 1.3060, Train Accuracy: 59.49%
# Epoch 23/100 - Train Loss: 1.2865, Train Accuracy: 60.27%
# Epoch 24/100 - Train Loss: 1.2669, Train Accuracy: 60.56%
# Epoch 25/100 - Train Loss: 1.2489, Train Accuracy: 61.03%
# [Epoch 25] Test Loss: 1.4918, Test Accuracy: 55.01%
# Epoch 26/100 - Train Loss: 1.2322, Train Accuracy: 61.77%
# Epoch 27/100 - Train Loss: 1.2154, Train Accuracy: 62.05%
# Epoch 28/100 - Train Loss: 1.2006, Train Accuracy: 62.60%
# Epoch 29/100 - Train Loss: 1.1855, Train Accuracy: 62.97%
# Epoch 30/100 - Train Loss: 1.1716, Train Accuracy: 63.54%
# [Epoch 30] Test Loss: 1.4567, Test Accuracy: 56.42%
# Epoch 31/100 - Train Loss: 1.1589, Train Accuracy: 63.82%
# Epoch 32/100 - Train Loss: 1.1455, Train Accuracy: 63.92%
# Epoch 33/100 - Train Loss: 1.1339, Train Accuracy: 64.27%
# Epoch 34/100 - Train Loss: 1.1216, Train Accuracy: 64.66%
# Epoch 35/100 - Train Loss: 1.1113, Train Accuracy: 64.82%
# [Epoch 35] Test Loss: 1.4290, Test Accuracy: 57.35%
# Epoch 36/100 - Train Loss: 1.1009, Train Accuracy: 65.15%
# Epoch 37/100 - Train Loss: 1.0912, Train Accuracy: 65.40%
# Epoch 38/100 - Train Loss: 1.0814, Train Accuracy: 65.61%
# Epoch 39/100 - Train Loss: 1.0722, Train Accuracy: 65.76%
# Epoch 40/100 - Train Loss: 1.0638, Train Accuracy: 66.11%
# [Epoch 40] Test Loss: 1.4112, Test Accuracy: 58.01%
# Epoch 41/100 - Train Loss: 1.0544, Train Accuracy: 66.46%
# Epoch 42/100 - Train Loss: 1.0465, Train Accuracy: 66.62%
# Epoch 43/100 - Train Loss: 1.0379, Train Accuracy: 66.91%
# Epoch 44/100 - Train Loss: 1.0309, Train Accuracy: 67.25%
# Epoch 45/100 - Train Loss: 1.0227, Train Accuracy: 67.29%
# [Epoch 45] Test Loss: 1.4067, Test Accuracy: 58.41%
# Epoch 46/100 - Train Loss: 1.0169, Train Accuracy: 67.52%
# Epoch 47/100 - Train Loss: 1.0089, Train Accuracy: 67.82%
# Epoch 48/100 - Train Loss: 1.0023, Train Accuracy: 68.02%
# Epoch 49/100 - Train Loss: 0.9962, Train Accuracy: 68.13%
# Epoch 50/100 - Train Loss: 0.9893, Train Accuracy: 68.37%
# [Epoch 50] Test Loss: 1.4021, Test Accuracy: 58.94%
# Epoch 51/100 - Train Loss: 0.9828, Train Accuracy: 68.57%
# Epoch 52/100 - Train Loss: 0.9764, Train Accuracy: 68.77%
# Epoch 53/100 - Train Loss: 0.9708, Train Accuracy: 69.02%
# Epoch 54/100 - Train Loss: 0.9637, Train Accuracy: 69.22%
# Epoch 55/100 - Train Loss: 0.9589, Train Accuracy: 69.45%
# [Epoch 55] Test Loss: 1.4036, Test Accuracy: 59.28%
# Epoch 56/100 - Train Loss: 0.9541, Train Accuracy: 69.71%
# Epoch 57/100 - Train Loss: 0.9473, Train Accuracy: 69.81%
# Epoch 58/100 - Train Loss: 0.9424, Train Accuracy: 69.88%
# Epoch 59/100 - Train Loss: 0.9369, Train Accuracy: 70.10%
# Epoch 60/100 - Train Loss: 0.9315, Train Accuracy: 70.36%
# [Epoch 60] Test Loss: 1.4012, Test Accuracy: 59.26%
# Epoch 61/100 - Train Loss: 0.9269, Train Accuracy: 70.29%
# Epoch 62/100 - Train Loss: 0.9217, Train Accuracy: 70.54%
# Epoch 63/100 - Train Loss: 0.9164, Train Accuracy: 70.91%
# Epoch 64/100 - Train Loss: 0.9113, Train Accuracy: 71.01%
# Epoch 65/100 - Train Loss: 0.9063, Train Accuracy: 71.19%
# [Epoch 65] Test Loss: 1.4030, Test Accuracy: 59.47%
# Epoch 66/100 - Train Loss: 0.9019, Train Accuracy: 71.21%
# Epoch 67/100 - Train Loss: 0.8974, Train Accuracy: 71.36%
# Epoch 68/100 - Train Loss: 0.8927, Train Accuracy: 71.65%
# Epoch 69/100 - Train Loss: 0.8890, Train Accuracy: 71.60%
# Epoch 70/100 - Train Loss: 0.8838, Train Accuracy: 71.93%
# [Epoch 70] Test Loss: 1.4101, Test Accuracy: 60.05%
# Epoch 71/100 - Train Loss: 0.8792, Train Accuracy: 72.05%
# Epoch 72/100 - Train Loss: 0.8750, Train Accuracy: 72.15%
# Epoch 73/100 - Train Loss: 0.8714, Train Accuracy: 72.35%
# Epoch 74/100 - Train Loss: 0.8675, Train Accuracy: 72.39%
# Epoch 75/100 - Train Loss: 0.8630, Train Accuracy: 72.59%
# [Epoch 75] Test Loss: 1.4176, Test Accuracy: 59.95%
# Epoch 76/100 - Train Loss: 0.8595, Train Accuracy: 72.79%
# Epoch 77/100 - Train Loss: 0.8543, Train Accuracy: 72.96%
# Epoch 78/100 - Train Loss: 0.8508, Train Accuracy: 72.98%
# Epoch 79/100 - Train Loss: 0.8464, Train Accuracy: 73.16%
# Epoch 80/100 - Train Loss: 0.8439, Train Accuracy: 73.28%
# [Epoch 80] Test Loss: 1.4227, Test Accuracy: 60.29%
# Epoch 81/100 - Train Loss: 0.8381, Train Accuracy: 73.53%
# Epoch 82/100 - Train Loss: 0.8348, Train Accuracy: 73.66%
# Epoch 83/100 - Train Loss: 0.8302, Train Accuracy: 73.64%
# Epoch 84/100 - Train Loss: 0.8270, Train Accuracy: 73.85%
# Epoch 85/100 - Train Loss: 0.8234, Train Accuracy: 74.15%
# [Epoch 85] Test Loss: 1.4374, Test Accuracy: 60.00%
# Epoch 86/100 - Train Loss: 0.8198, Train Accuracy: 74.20%
# Epoch 87/100 - Train Loss: 0.8160, Train Accuracy: 74.20%
# Epoch 88/100 - Train Loss: 0.8126, Train Accuracy: 74.31%
# Epoch 89/100 - Train Loss: 0.8094, Train Accuracy: 74.44%
# Epoch 90/100 - Train Loss: 0.8047, Train Accuracy: 74.53%
# [Epoch 90] Test Loss: 1.4463, Test Accuracy: 59.92%
# Epoch 91/100 - Train Loss: 0.8011, Train Accuracy: 74.84%
# Epoch 92/100 - Train Loss: 0.7982, Train Accuracy: 74.81%
# Epoch 93/100 - Train Loss: 0.7948, Train Accuracy: 74.96%
# Epoch 94/100 - Train Loss: 0.7910, Train Accuracy: 75.19%
# Epoch 95/100 - Train Loss: 0.7872, Train Accuracy: 75.04%
# [Epoch 95] Test Loss: 1.4565, Test Accuracy: 60.05%
# Epoch 96/100 - Train Loss: 0.7845, Train Accuracy: 75.24%
# Epoch 97/100 - Train Loss: 0.7810, Train Accuracy: 75.54%
# Epoch 98/100 - Train Loss: 0.7778, Train Accuracy: 75.56%
# Epoch 99/100 - Train Loss: 0.7740, Train Accuracy: 75.75%
# Epoch 100/100 - Train Loss: 0.7711, Train Accuracy: 75.67%
# [Epoch 100] Test Loss: 1.4680, Test Accuracy: 60.11%
# [use_mask=True, reg=None] Final Test Accuracy: 60.11%, Test Loss: 1.4680
# Run data saved to runs_20Newsgroups/20250711_143151_act-ReLU_mask-True_thresh-0.69_reg-None_epochs-100-20Newsgroups
# 635.737895488739
# Epoch 1/100 - Train Loss: 2.9969, Train Accuracy: 5.23%
# Epoch 2/100 - Train Loss: 2.9890, Train Accuracy: 6.94%
# Epoch 3/100 - Train Loss: 2.9552, Train Accuracy: 14.03%
# Epoch 4/100 - Train Loss: 2.8538, Train Accuracy: 18.77%
# Epoch 5/100 - Train Loss: 2.7089, Train Accuracy: 18.82%
# [Epoch 5] Test Loss: 2.6491, Test Accuracy: 20.16%
# Epoch 6/100 - Train Loss: 2.5864, Train Accuracy: 21.61%
# Epoch 7/100 - Train Loss: 2.4947, Train Accuracy: 25.89%
# Epoch 8/100 - Train Loss: 2.4213, Train Accuracy: 28.30%
# Epoch 9/100 - Train Loss: 2.3585, Train Accuracy: 29.47%
# Epoch 10/100 - Train Loss: 2.3018, Train Accuracy: 32.57%
# [Epoch 10] Test Loss: 2.3030, Test Accuracy: 32.55%
# Epoch 11/100 - Train Loss: 2.2478, Train Accuracy: 34.35%
# Epoch 12/100 - Train Loss: 2.1962, Train Accuracy: 36.59%
# Epoch 13/100 - Train Loss: 2.1463, Train Accuracy: 39.04%
# Epoch 14/100 - Train Loss: 2.0986, Train Accuracy: 39.22%
# Epoch 15/100 - Train Loss: 2.0528, Train Accuracy: 40.38%
# [Epoch 15] Test Loss: 2.0834, Test Accuracy: 38.28%
# Epoch 16/100 - Train Loss: 2.0090, Train Accuracy: 42.55%
# Epoch 17/100 - Train Loss: 1.9677, Train Accuracy: 43.26%
# Epoch 18/100 - Train Loss: 1.9293, Train Accuracy: 44.29%
# Epoch 19/100 - Train Loss: 1.8935, Train Accuracy: 44.89%
# Epoch 20/100 - Train Loss: 1.8600, Train Accuracy: 46.26%
# [Epoch 20] Test Loss: 1.9190, Test Accuracy: 42.97%
# Epoch 21/100 - Train Loss: 1.8283, Train Accuracy: 46.50%
# Epoch 22/100 - Train Loss: 1.7983, Train Accuracy: 47.37%
# Epoch 23/100 - Train Loss: 1.7706, Train Accuracy: 48.43%
# Epoch 24/100 - Train Loss: 1.7442, Train Accuracy: 48.91%
# Epoch 25/100 - Train Loss: 1.7197, Train Accuracy: 49.37%
# [Epoch 25] Test Loss: 1.8029, Test Accuracy: 45.68%
# Epoch 26/100 - Train Loss: 1.6969, Train Accuracy: 49.91%
# Epoch 27/100 - Train Loss: 1.6739, Train Accuracy: 50.90%
# Epoch 28/100 - Train Loss: 1.6539, Train Accuracy: 51.50%
# Epoch 29/100 - Train Loss: 1.6327, Train Accuracy: 52.08%
# Epoch 30/100 - Train Loss: 1.6130, Train Accuracy: 52.75%
# [Epoch 30] Test Loss: 1.7177, Test Accuracy: 48.83%
# Epoch 31/100 - Train Loss: 1.5941, Train Accuracy: 53.45%
# Epoch 32/100 - Train Loss: 1.5767, Train Accuracy: 54.00%
# Epoch 33/100 - Train Loss: 1.5593, Train Accuracy: 54.58%
# Epoch 34/100 - Train Loss: 1.5422, Train Accuracy: 55.39%
# Epoch 35/100 - Train Loss: 1.5260, Train Accuracy: 55.70%
# [Epoch 35] Test Loss: 1.6521, Test Accuracy: 51.46%
# Epoch 36/100 - Train Loss: 1.5103, Train Accuracy: 56.25%
# Epoch 37/100 - Train Loss: 1.4947, Train Accuracy: 56.84%
# Epoch 38/100 - Train Loss: 1.4797, Train Accuracy: 56.98%
# Epoch 39/100 - Train Loss: 1.4650, Train Accuracy: 57.56%
# Epoch 40/100 - Train Loss: 1.4515, Train Accuracy: 57.72%
# [Epoch 40] Test Loss: 1.5931, Test Accuracy: 53.24%
# Epoch 41/100 - Train Loss: 1.4366, Train Accuracy: 58.51%
# Epoch 42/100 - Train Loss: 1.4232, Train Accuracy: 58.53%
# Epoch 43/100 - Train Loss: 1.4105, Train Accuracy: 59.05%
# Epoch 44/100 - Train Loss: 1.3978, Train Accuracy: 59.49%
# Epoch 45/100 - Train Loss: 1.3850, Train Accuracy: 59.77%
# [Epoch 45] Test Loss: 1.5437, Test Accuracy: 54.69%
# Epoch 46/100 - Train Loss: 1.3734, Train Accuracy: 60.22%
# Epoch 47/100 - Train Loss: 1.3616, Train Accuracy: 60.52%
# Epoch 48/100 - Train Loss: 1.3500, Train Accuracy: 60.85%
# Epoch 49/100 - Train Loss: 1.3381, Train Accuracy: 61.36%
# Epoch 50/100 - Train Loss: 1.3277, Train Accuracy: 61.65%
# [Epoch 50] Test Loss: 1.5030, Test Accuracy: 55.81%
# Epoch 51/100 - Train Loss: 1.3167, Train Accuracy: 61.79%
# Epoch 52/100 - Train Loss: 1.3060, Train Accuracy: 61.86%
# Epoch 53/100 - Train Loss: 1.2959, Train Accuracy: 62.35%
# Epoch 54/100 - Train Loss: 1.2857, Train Accuracy: 62.44%
# Epoch 55/100 - Train Loss: 1.2776, Train Accuracy: 62.66%
# [Epoch 55] Test Loss: 1.4695, Test Accuracy: 56.31%
# Epoch 56/100 - Train Loss: 1.2672, Train Accuracy: 62.88%
# Epoch 57/100 - Train Loss: 1.2589, Train Accuracy: 63.18%
# Epoch 58/100 - Train Loss: 1.2492, Train Accuracy: 63.50%
# Epoch 59/100 - Train Loss: 1.2413, Train Accuracy: 63.46%
# Epoch 60/100 - Train Loss: 1.2325, Train Accuracy: 63.81%
# [Epoch 60] Test Loss: 1.4401, Test Accuracy: 57.24%
# Epoch 61/100 - Train Loss: 1.2239, Train Accuracy: 63.98%
# Epoch 62/100 - Train Loss: 1.2165, Train Accuracy: 64.04%
# Epoch 63/100 - Train Loss: 1.2086, Train Accuracy: 64.35%
# Epoch 64/100 - Train Loss: 1.2014, Train Accuracy: 64.56%
# Epoch 65/100 - Train Loss: 1.1933, Train Accuracy: 64.62%
# [Epoch 65] Test Loss: 1.4180, Test Accuracy: 58.36%
# Epoch 66/100 - Train Loss: 1.1866, Train Accuracy: 64.98%
# Epoch 67/100 - Train Loss: 1.1797, Train Accuracy: 64.82%
# Epoch 68/100 - Train Loss: 1.1731, Train Accuracy: 65.34%
# Epoch 69/100 - Train Loss: 1.1667, Train Accuracy: 65.29%
# Epoch 70/100 - Train Loss: 1.1601, Train Accuracy: 65.60%
# [Epoch 70] Test Loss: 1.3985, Test Accuracy: 58.97%
# Epoch 71/100 - Train Loss: 1.1536, Train Accuracy: 65.85%
# Epoch 72/100 - Train Loss: 1.1471, Train Accuracy: 65.80%
# Epoch 73/100 - Train Loss: 1.1410, Train Accuracy: 66.01%
# Epoch 74/100 - Train Loss: 1.1352, Train Accuracy: 66.25%
# Epoch 75/100 - Train Loss: 1.1289, Train Accuracy: 66.20%
# [Epoch 75] Test Loss: 1.3848, Test Accuracy: 59.39%
# Epoch 76/100 - Train Loss: 1.1237, Train Accuracy: 66.46%
# Epoch 77/100 - Train Loss: 1.1187, Train Accuracy: 66.49%
# Epoch 78/100 - Train Loss: 1.1130, Train Accuracy: 66.56%
# Epoch 79/100 - Train Loss: 1.1089, Train Accuracy: 66.63%
# Epoch 80/100 - Train Loss: 1.1024, Train Accuracy: 66.75%
# [Epoch 80] Test Loss: 1.3712, Test Accuracy: 59.73%
# Epoch 81/100 - Train Loss: 1.0972, Train Accuracy: 66.98%
# Epoch 82/100 - Train Loss: 1.0920, Train Accuracy: 67.05%
# Epoch 83/100 - Train Loss: 1.0877, Train Accuracy: 67.13%
# Epoch 84/100 - Train Loss: 1.0826, Train Accuracy: 67.34%
# Epoch 85/100 - Train Loss: 1.0775, Train Accuracy: 67.52%
# [Epoch 85] Test Loss: 1.3592, Test Accuracy: 60.32%
# Epoch 86/100 - Train Loss: 1.0731, Train Accuracy: 67.51%
# Epoch 87/100 - Train Loss: 1.0688, Train Accuracy: 67.68%
# Epoch 88/100 - Train Loss: 1.0640, Train Accuracy: 67.91%
# Epoch 89/100 - Train Loss: 1.0598, Train Accuracy: 67.91%
# Epoch 90/100 - Train Loss: 1.0557, Train Accuracy: 68.02%
# [Epoch 90] Test Loss: 1.3512, Test Accuracy: 60.58%
# Epoch 91/100 - Train Loss: 1.0517, Train Accuracy: 68.00%
# Epoch 92/100 - Train Loss: 1.0471, Train Accuracy: 68.23%
# Epoch 93/100 - Train Loss: 1.0439, Train Accuracy: 68.38%
# Epoch 94/100 - Train Loss: 1.0392, Train Accuracy: 68.29%
# Epoch 95/100 - Train Loss: 1.0355, Train Accuracy: 68.56%
# [Epoch 95] Test Loss: 1.3451, Test Accuracy: 60.82%
# Epoch 96/100 - Train Loss: 1.0307, Train Accuracy: 68.55%
# Epoch 97/100 - Train Loss: 1.0277, Train Accuracy: 68.71%
# Epoch 98/100 - Train Loss: 1.0232, Train Accuracy: 68.94%
# Epoch 99/100 - Train Loss: 1.0212, Train Accuracy: 68.64%
# Epoch 100/100 - Train Loss: 1.0180, Train Accuracy: 69.02%
# [Epoch 100] Test Loss: 1.3382, Test Accuracy: 60.90%
# [use_mask=True, reg=None] Final Test Accuracy: 60.90%, Test Loss: 1.3382
# Run data saved to runs_20Newsgroups/20250711_144142_act-ReLU_mask-True_thresh-1.39_reg-None_epochs-100-20Newsgroups
# 590.2250170707703
# Epoch 1/100 - Train Loss: 2.9979, Train Accuracy: 5.23%
# Epoch 2/100 - Train Loss: 2.9971, Train Accuracy: 5.23%
# Epoch 3/100 - Train Loss: 2.9965, Train Accuracy: 5.23%
# Epoch 4/100 - Train Loss: 2.9960, Train Accuracy: 5.23%
# Epoch 5/100 - Train Loss: 2.9955, Train Accuracy: 5.23%
# [Epoch 5] Test Loss: 2.9951, Test Accuracy: 5.23%
# Epoch 6/100 - Train Loss: 2.9950, Train Accuracy: 5.23%
# Epoch 7/100 - Train Loss: 2.9944, Train Accuracy: 5.23%
# Epoch 8/100 - Train Loss: 2.9939, Train Accuracy: 6.22%
# Epoch 9/100 - Train Loss: 2.9933, Train Accuracy: 5.25%
# Epoch 10/100 - Train Loss: 2.9927, Train Accuracy: 8.67%
# [Epoch 10] Test Loss: 2.9923, Test Accuracy: 7.21%
# Epoch 11/100 - Train Loss: 2.9922, Train Accuracy: 5.41%
# Epoch 12/100 - Train Loss: 2.9917, Train Accuracy: 5.33%
# Epoch 13/100 - Train Loss: 2.9911, Train Accuracy: 5.33%
# Epoch 14/100 - Train Loss: 2.9906, Train Accuracy: 5.31%
# Epoch 15/100 - Train Loss: 2.9901, Train Accuracy: 5.31%
# [Epoch 15] Test Loss: 2.9896, Test Accuracy: 5.31%
# Epoch 16/100 - Train Loss: 2.9895, Train Accuracy: 5.44%
# Epoch 17/100 - Train Loss: 2.9889, Train Accuracy: 7.14%
# Epoch 18/100 - Train Loss: 2.9883, Train Accuracy: 8.74%
# Epoch 19/100 - Train Loss: 2.9876, Train Accuracy: 10.52%
# Epoch 20/100 - Train Loss: 2.9868, Train Accuracy: 9.09%
# [Epoch 20] Test Loss: 2.9864, Test Accuracy: 10.42%
# Epoch 21/100 - Train Loss: 2.9860, Train Accuracy: 9.37%
# Epoch 22/100 - Train Loss: 2.9851, Train Accuracy: 10.75%
# Epoch 23/100 - Train Loss: 2.9840, Train Accuracy: 11.04%
# Epoch 24/100 - Train Loss: 2.9828, Train Accuracy: 15.56%
# Epoch 25/100 - Train Loss: 2.9816, Train Accuracy: 17.77%
# [Epoch 25] Test Loss: 2.9811, Test Accuracy: 18.20%
# Epoch 26/100 - Train Loss: 2.9802, Train Accuracy: 20.04%
# Epoch 27/100 - Train Loss: 2.9786, Train Accuracy: 19.92%
# Epoch 28/100 - Train Loss: 2.9769, Train Accuracy: 22.50%
# Epoch 29/100 - Train Loss: 2.9750, Train Accuracy: 24.92%
# Epoch 30/100 - Train Loss: 2.9730, Train Accuracy: 24.02%
# [Epoch 30] Test Loss: 2.9725, Test Accuracy: 24.06%
# Epoch 31/100 - Train Loss: 2.9708, Train Accuracy: 22.54%
# Epoch 32/100 - Train Loss: 2.9684, Train Accuracy: 25.03%
# Epoch 33/100 - Train Loss: 2.9659, Train Accuracy: 22.86%
# Epoch 34/100 - Train Loss: 2.9631, Train Accuracy: 23.53%
# Epoch 35/100 - Train Loss: 2.9601, Train Accuracy: 22.05%
# [Epoch 35] Test Loss: 2.9597, Test Accuracy: 21.70%
# Epoch 36/100 - Train Loss: 2.9570, Train Accuracy: 22.29%
# Epoch 37/100 - Train Loss: 2.9537, Train Accuracy: 23.59%
# Epoch 38/100 - Train Loss: 2.9501, Train Accuracy: 22.49%
# Epoch 39/100 - Train Loss: 2.9464, Train Accuracy: 21.48%
# Epoch 40/100 - Train Loss: 2.9423, Train Accuracy: 21.75%
# [Epoch 40] Test Loss: 2.9420, Test Accuracy: 21.78%
# Epoch 41/100 - Train Loss: 2.9381, Train Accuracy: 23.03%
# Epoch 42/100 - Train Loss: 2.9336, Train Accuracy: 22.64%
# Epoch 43/100 - Train Loss: 2.9289, Train Accuracy: 23.60%
# Epoch 44/100 - Train Loss: 2.9240, Train Accuracy: 23.57%
# Epoch 45/100 - Train Loss: 2.9187, Train Accuracy: 22.67%
# [Epoch 45] Test Loss: 2.9188, Test Accuracy: 22.20%
# Epoch 46/100 - Train Loss: 2.9133, Train Accuracy: 23.91%
# Epoch 47/100 - Train Loss: 2.9077, Train Accuracy: 23.12%
# Epoch 48/100 - Train Loss: 2.9018, Train Accuracy: 23.59%
# Epoch 49/100 - Train Loss: 2.8957, Train Accuracy: 24.59%
# Epoch 50/100 - Train Loss: 2.8893, Train Accuracy: 25.00%
# [Epoch 50] Test Loss: 2.8901, Test Accuracy: 23.16%
# Epoch 51/100 - Train Loss: 2.8828, Train Accuracy: 25.16%
# Epoch 52/100 - Train Loss: 2.8760, Train Accuracy: 25.21%
# Epoch 53/100 - Train Loss: 2.8690, Train Accuracy: 26.12%
# Epoch 54/100 - Train Loss: 2.8617, Train Accuracy: 26.21%
# Epoch 55/100 - Train Loss: 2.8542, Train Accuracy: 26.92%
# [Epoch 55] Test Loss: 2.8559, Test Accuracy: 24.14%
# Epoch 56/100 - Train Loss: 2.8466, Train Accuracy: 26.45%
# Epoch 57/100 - Train Loss: 2.8386, Train Accuracy: 27.03%
# Epoch 58/100 - Train Loss: 2.8305, Train Accuracy: 27.60%
# Epoch 59/100 - Train Loss: 2.8220, Train Accuracy: 28.54%
# Epoch 60/100 - Train Loss: 2.8136, Train Accuracy: 28.09%
# [Epoch 60] Test Loss: 2.8164, Test Accuracy: 26.68%
# Epoch 61/100 - Train Loss: 2.8047, Train Accuracy: 28.87%
# Epoch 62/100 - Train Loss: 2.7959, Train Accuracy: 28.93%
# Epoch 63/100 - Train Loss: 2.7865, Train Accuracy: 29.66%
# Epoch 64/100 - Train Loss: 2.7772, Train Accuracy: 29.76%
# Epoch 65/100 - Train Loss: 2.7676, Train Accuracy: 30.41%
# [Epoch 65] Test Loss: 2.7721, Test Accuracy: 28.06%
# Epoch 66/100 - Train Loss: 2.7577, Train Accuracy: 30.25%
# Epoch 67/100 - Train Loss: 2.7479, Train Accuracy: 30.96%
# Epoch 68/100 - Train Loss: 2.7380, Train Accuracy: 30.81%
# Epoch 69/100 - Train Loss: 2.7278, Train Accuracy: 31.39%
# Epoch 70/100 - Train Loss: 2.7176, Train Accuracy: 31.84%
# [Epoch 70] Test Loss: 2.7240, Test Accuracy: 29.12%
# Epoch 71/100 - Train Loss: 2.7075, Train Accuracy: 31.51%
# Epoch 72/100 - Train Loss: 2.6968, Train Accuracy: 32.17%
# Epoch 73/100 - Train Loss: 2.6861, Train Accuracy: 32.45%
# Epoch 74/100 - Train Loss: 2.6754, Train Accuracy: 32.91%
# Epoch 75/100 - Train Loss: 2.6645, Train Accuracy: 32.81%
# [Epoch 75] Test Loss: 2.6727, Test Accuracy: 31.35%
# Epoch 76/100 - Train Loss: 2.6537, Train Accuracy: 33.01%
# Epoch 77/100 - Train Loss: 2.6428, Train Accuracy: 33.40%
# Epoch 78/100 - Train Loss: 2.6316, Train Accuracy: 33.46%
# Epoch 79/100 - Train Loss: 2.6207, Train Accuracy: 33.69%
# Epoch 80/100 - Train Loss: 2.6097, Train Accuracy: 34.09%
# [Epoch 80] Test Loss: 2.6200, Test Accuracy: 32.41%
# Epoch 81/100 - Train Loss: 2.5987, Train Accuracy: 34.03%
# Epoch 82/100 - Train Loss: 2.5876, Train Accuracy: 34.24%
# Epoch 83/100 - Train Loss: 2.5765, Train Accuracy: 34.45%
# Epoch 84/100 - Train Loss: 2.5651, Train Accuracy: 34.72%
# Epoch 85/100 - Train Loss: 2.5540, Train Accuracy: 34.90%
# [Epoch 85] Test Loss: 2.5670, Test Accuracy: 33.55%
# Epoch 86/100 - Train Loss: 2.5431, Train Accuracy: 34.97%
# Epoch 87/100 - Train Loss: 2.5320, Train Accuracy: 35.01%
# Epoch 88/100 - Train Loss: 2.5210, Train Accuracy: 35.42%
# Epoch 89/100 - Train Loss: 2.5101, Train Accuracy: 35.25%
# Epoch 90/100 - Train Loss: 2.4991, Train Accuracy: 35.63%
# [Epoch 90] Test Loss: 2.5145, Test Accuracy: 34.91%
# Epoch 91/100 - Train Loss: 2.4883, Train Accuracy: 35.77%
# Epoch 92/100 - Train Loss: 2.4773, Train Accuracy: 35.78%
# Epoch 93/100 - Train Loss: 2.4668, Train Accuracy: 36.05%
# Epoch 94/100 - Train Loss: 2.4562, Train Accuracy: 36.09%
# Epoch 95/100 - Train Loss: 2.4455, Train Accuracy: 36.12%
# [Epoch 95] Test Loss: 2.4634, Test Accuracy: 35.38%
# Epoch 96/100 - Train Loss: 2.4348, Train Accuracy: 36.56%
# Epoch 97/100 - Train Loss: 2.4243, Train Accuracy: 36.28%
# Epoch 98/100 - Train Loss: 2.4136, Train Accuracy: 36.59%
# Epoch 99/100 - Train Loss: 2.4034, Train Accuracy: 36.59%
# Epoch 100/100 - Train Loss: 2.3931, Train Accuracy: 36.77%
# [Epoch 100] Test Loss: 2.4139, Test Accuracy: 35.73%
# [use_mask=True, reg=None] Final Test Accuracy: 35.73%, Test Loss: 2.4139
# Run data saved to runs_20Newsgroups/20250711_145029_act-ReLU_mask-True_thresh-2.3_reg-None_epochs-100-20Newsgroups
# 527.480295419693
# 52.451095008850096

# %%
all_entropies = {}
for label, the_model in model_results.items():
    entropies = []
    for name, layer in the_model.named_modules():
        if isinstance(layer, (MaskedLinear)):
            entropies.append(layer.entropy.cpu().item())
    all_entropies[label] = entropies

all_entropies
# Out:
# {'ReLU_NoMask_L1': [12.618078231811523,
#   10.649311065673828,
#   9.33981704711914,
#   6.927118301391602],
#  'ReLU_Mask_NoReg_t1': [11.992117881774902,
#   10.477645874023438,
#   9.191641807556152,
#   6.907275199890137],
#  'ReLU_Mask_NoReg_t3': [11.27175235748291,
#   9.99704360961914,
#   8.596906661987305,
#   6.392963409423828],
#  'ReLU_Mask_NoReg_t4': [10.478978157043457,
#   9.246452331542969,
#   7.72914981842041,
#   5.588466167449951],
#  'ReLU_Mask_NoReg_t5': [8.878198623657227,
#   6.7647600173950195,
#   4.839975833892822,
#   3.3464107513427734]}

# %%
print(4)
# Out:
# 4

# %%
# Ensure plot directory exists
plot_dir = "runs_"+notebook_name+"/"+str(datetime.now().strftime("%Y%m%d_%H%M%S"))+"_plots"
os.makedirs(plot_dir, exist_ok=True)

# Plotting layer-wise entropy
plt.figure(figsize=(10, 6))
for label, entropies in all_entropies.items():
    plt.plot(range(1, len(entropies)+1), entropies, label=label)
plt.xlabel('Layer Index')
plt.ylabel('Entropy')
plt.title('Layer-wise Entropy across Model Variants')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{plot_dir}/Entropy.png")
plt.show()

# Test accuracy
plt.figure()
for label, accs in test_accs.items():
    plt.plot(range(5, 5 * len(accs) + 1, 5), accs, label=label)
plt.title("Test accuracy")
plt.ylabel('Test Accuracy')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Test_Accuracy.png")
plt.show()

# Test loss
plt.figure()
for label, loss in test_losses.items():
    plt.plot(range(5, 5 * len(accs) + 1, 5), loss, label=label)
plt.title("Test loss")
plt.ylabel('Test loss')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Test_loss.png")
plt.show()

# Speed
plt.figure()
plt.bar(times.keys(), times.values(), color='skyblue')
plt.ylabel('Speed')
plt.title('Final Speed across Model Variants')
plt.xticks(rotation=20)
plt.tight_layout()
plt.savefig(f"{plot_dir}/Speed.png")
plt.show()

# Train accuracy
plt.figure()
for label, accs in train_accs.items():
    plt.plot(range(1, len(accs)+1), accs, label=label)
plt.title("Train accuracy")
plt.ylabel('Train Accuracy')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Train_Accuracy.png")
plt.show()

# Train loss
plt.figure()
for label, loss in train_losses.items():
    plt.plot(range(1, len(loss)+1), loss, label=label)
plt.title("Train loss")
plt.ylabel('Train loss')
plt.xlabel("Epochs")
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend()
plt.savefig(f"{plot_dir}/Train_loss.png")
plt.show()

# %%
def get_squared_weight_matrix(layer):
    # # For Conv layers, flatten input/output dimensions
    # if isinstance(layer, MaskedConv):
    #     # Shape: [out_channels, in_channels, kH, kW]
    #     M = layer.weight.view(layer.out_channels, -1)  # [out_c, in_c * kH * kW]
    if isinstance(layer, MaskedLinear):
        # Shape: [out_features, in_features]
        M = layer.weight
        W = torch.pow(10,-layer.wval(layer.weight))
    else:
        return None
    return M, W

def compute_g_value(model):
    layers = []
    W_vals = []
    for layer in model.modules():
        if isinstance(layer, (MaskedLinear)):
            M, W = get_squared_weight_matrix(layer)
            if M is not None:
                layers.append(M)
            if W is not None:
                W_vals.append(W)
    numer = 0.0
    denom = 0.0

    for i in range(len(layers) - 1):
        M1 = layers[i]
        M2 = layers[i+1]

        # M1: [out1, in1]; M2: [out2, in2] → treat shared dim as "middle"
        # So transpose M1 to [in1, out1] and M2 to [in2, out2]
        # sum over matching dimension (out1 == in2)
        M1_sq = M1.pow(2)  # shape: [out1, in1]
        M2_sq = M2.pow(2)  # shape: [out2, in2]
        
        # Align dimension for matching: M1.T: [in1, out1], M2: [out2, in2] ⇒ match on out1 == in2
        if M1.shape[0] != M2.shape[1]:
            # Skip incompatible shapes
            continue

        # Compute: sum_j (sum_i w_{ij}^2) * (sum_k w_{jk}^2)
        # That is, for each shared index j (layer output/input), multiply the sums of incoming and outgoing squared weights
        incoming = M1_sq.sum(dim=1)  # size: [out1] == [shared]
        outgoing = M2_sq.sum(dim=0)  # size: [in2] == [shared]
        numer += (incoming * outgoing).sum().item()

    for i in range(len(layers) - 1):
        M1 = layers[i]
        M2 = layers[i+1]

        W1 = W_vals[i]
        W2 = W_vals[i+1]
        
        # M1: [out1, in1]; M2: [out2, in2] → treat shared dim as "middle"
        # So transpose M1 to [in1, out1] and M2 to [in2, out2]
        # sum over matching dimension (out1 == in2)
        M1_sq = M1.pow(2) / W1
        M2_sq = M2.pow(2) / W2

        # Align dimension for matching: M1.T: [in1, out1], M2: [out2, in2] ⇒ match on out1 == in2
        if M1.shape[0] != M2.shape[1]:
            # Skip incompatible shapes
            continue

        # Compute: sum_j (sum_i w_{ij}^2) * (sum_k w_{jk}^2)
        # That is, for each shared index j (layer output/input), multiply the sums of incoming and outgoing squared weights
        incoming = M1_sq.sum(dim=1)  # size: [out1] == [shared]
        outgoing = M2_sq.sum(dim=0)  # size: [in2] == [shared]
        denom += (incoming * outgoing).sum().item()
        torch.set_printoptions(profile="default")

    return numer/denom

# %%
print("Regarding aggregated w-value")
for label in model_results.keys():
    print(label)
    print(compute_g_value(model_results[label]))
#compute_g_value(model_results["ReLU_NoMask_NoReg"])
# Out:
# Regarding aggregated w-value
# ReLU_NoMask_L1
# 8.88734128178042e-29
# ReLU_Mask_NoReg_t1
# 7.092572505505912e-26
# ReLU_Mask_NoReg_t3
# 2.0875517060918516e-33
# ReLU_Mask_NoReg_t4
# 2.1310090133542955e-35
# ReLU_Mask_NoReg_t5
# 0.0

# %%
def plot_weight_distributions(model=None, weight_data=None, model_name=None):
    """
    Plot weight and w-value histograms for each layer, either from:
    - a model (with .wval method on layers)
    - OR a dict (state_dict-style) with keys like 'layer.weight' and 'layer.w_values'
    """
    if model is None and weight_data is None:
        raise ValueError("Provide either a model or weight_data")

    weight_layers = []
    wval_layers = []
    layer_names = []

    if weight_data is not None:
        # Group .weight and .w_values by layer name
        grouped = defaultdict(dict)
        for full_name, tensor in weight_data.items():
            *layer_parts, attr = full_name.split('.')
            layer_name = '.'.join(layer_parts)
            grouped[layer_name][attr] = tensor

        for layer_name, tensors in grouped.items():
            if "weight" in tensors and "w_values" in tensors:
                try:
                    W = tensors["weight"].detach().cpu().flatten().numpy()
                    W_val = tensors["w_values"].detach().cpu().flatten().numpy()
                    weight_layers.append(W)
                    wval_layers.append(W_val)
                    layer_names.append(layer_name)
                except Exception as e:
                    print(f"Skipping {layer_name} due to error: {e}")

    elif model is not None:
        # Use the model's layers directly
        for name, layer in model.named_modules():
            if hasattr(layer, "weight") and hasattr(layer, "w_values"):
                try:
                    W = layer.weight.detach().cpu().flatten().numpy()
                    #W_val = layer.wval(layer.weight).detach().cpu().flatten().numpy()
                    W_val = layer.w_values.detach().cpu().flatten().numpy()
                    print(W_val)
                    weight_layers.append(W)
                    wval_layers.append(W_val)
                    layer_names.append(name)
                except Exception as e:
                    print(f"Skipping layer {name} due to error: {e}")

    num_layers = len(weight_layers)
    if num_layers == 0:
        print("No valid layers found with both weights and w-values.")
        return

    plt.figure(figsize=(12, 4 * num_layers))

    # Plot weights
    for i, (weights, name) in enumerate(zip(weight_layers, layer_names)):
        plt.subplot(num_layers, 2, 2 * i + 1)
        sns.histplot(weights, binwidth=0.01, kde=False, color='steelblue')
        plt.title(f"Weight Distribution - {name}")
        plt.xlabel("Weight Value")
        plt.ylabel("Frequency")
        plt.xlim([-1, 1])

    # Plot w-values
    for i, (wvals, name) in enumerate(zip(wval_layers, layer_names)):
        plt.subplot(num_layers, 2, 2 * i + 2)
        sns.histplot(wvals, binwidth=0.1, kde=False, color='darkorange')
        plt.title(f"W-Value Distribution - {name}")
        plt.xlabel("-ln(W-Value)")
        plt.ylabel("Frequency")
        plt.xlim([0, 4])

    plt.tight_layout()
    #os.makedirs(plot_dir+"-"+model_name, exist_ok=True)
    plt.savefig(f"{plot_dir}-{model_name}-W_WVs.png")
    plt.show()

# %%
model = "ReLU_NoMask_L1"
plot_weight_distributions(model=model_results[model], model_name=model)
# Out:
# [0.60031974 0.11925872 0.44760862 ... 0.5798938  0.9585216  0.6203904 ]
# [ 0.31219465  0.39677423 10.948557   ...  3.430815    0.60832334
#   1.2753991 ]
# [1.8972425  1.7546271  0.25445807 ... 1.955903   0.21718085 0.07217321]
# [ 0.67753375  0.02878287  0.09861168 ...  0.3144965  -0.
#   1.208225  ]

# %%
model = "ReLU_Mask_NoReg_t4"
plot_weight_distributions(model=model_results[model], model_name=model)
# Out:
# [0.37213725 0.37213725 0.11925872 ... 0.21497117 0.31590745 0.25183183]
# [0.08390968 0.19693886 0.39018625 ... 7.2716985  0.26358268 0.12062242]
# [7.030855   3.6774306  0.3659658  ... 1.2963636  0.40909675 1.5295241 ]
# [0.39160135 0.36991313 0.30879164 ... 0.3561563  0.8151552  0.0503698 ]

# %%
model = "ReLU_Mask_NoReg_t3"
plot_weight_distributions(model=model_results[model], model_name=model)
# Out:
# [0.44760862 0.25183183 0.11925872 ... 0.17252445 0.17252445 2.0961835 ]
# [0.3630956  1.0338569  2.0036147  ... 3.9607382  3.4097626  0.12062242]
# [0.59447086 2.5636446  3.3198662  ... 0.89511395 0.18006107 0.91855985]
# [0.3126028  3.7598882  0.3716097  ... 0.3473817  0.48934925 0.0583812 ]

# %%
model = "ReLU_Mask_NoReg_t5"
plot_weight_distributions(model=model_results[model], model_name=model)
# Out:
# [0.3447758  0.37213725 0.11925872 ... 0.21497117 0.4233762  0.2851314 ]
# [0.3630956 0.9389059 2.3103974 ... 2.8644054 2.2361867 0.6537166]
# [1.6474684  1.9809184  1.058638   ... 1.294493   0.40909675 1.7477658 ]
# [0.5231447  0.49221504 0.4093826  ... 0.6592717  1.6139121  0.0938207 ]

# %%
plot_weight_distributions(baseline_model)

# %%
model = "ReLU_Mask_NoReg_t1"
plot_weight_distributions(model=model_results[model], model_name=model)
# Out:
# [ 0.21497117 -0.         -0.         ... -0.         -0.
#   2.057676  ]
# [0.9473094  0.08390968 5.2678986  ... 6.615596   0.08390968 0.05864682]
# [4.3253655  2.4891574  1.759769   ... 1.6125106  0.09410919 0.17426756]
# [0.0583812  1.9208927  0.09861168 ... 0.0779324  0.08352607 0.04094341]

# %%
#m_75 = torch.load('runs/20250710_141920_act-ReLU_mask-True_thresh-0.69_reg-None_epochs-5-20Newsgroups/model.pth')
